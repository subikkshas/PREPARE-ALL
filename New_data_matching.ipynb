# %% [markdown]
# <a href="https://colab.research.google.com/github/subikkshas/PREPARE-ALL/blob/main/New_data_matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.16.5)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 8.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.5.0

# %%
import pandas as pd
import numpy as np
import os
import optuna
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from typing import Dict, List, Tuple, Union
from sklearn.preprocessing import OneHotEncoder
from google.colab import drive
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import average_precision_score, precision_recall_curve, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from xgboost import XGBClassifier

# %%
def load_train_test_data(load_path='/content/drive/MyDrive/Prepare all data/'):
    # Mount Google Drive (if not already mounted)
    try:
        drive.mount('/content/drive')
        print("Google Drive mounted successfully.")
    except:
        print("Google Drive already mounted or mounting failed.")

    # Load the data files
    try:
        loaded_X_train = pd.read_csv(os.path.join(load_path, 'X_train_encoded.csv'))
        loaded_y_train = pd.read_csv(os.path.join(load_path, 'y_train_encoded.csv'))
        loaded_X_test = pd.read_csv(os.path.join(load_path, 'X_test_encoded.csv'))
        loaded_y_test = pd.read_csv(os.path.join(load_path, 'y_test_encoded.csv'))

        print("Data loaded successfully!")
        print(f"X_train shape: {loaded_X_train.shape}")
        print(f"y_train shape: {loaded_y_train.shape}")
        print(f"X_test shape: {loaded_X_test.shape}")
        print(f"y_test shape: {loaded_y_test.shape}")

        return loaded_X_train, loaded_y_train, loaded_X_test, loaded_y_test

    except FileNotFoundError as e:
        print(f"Error: File not found - {e}")
        return None, None, None, None
    except Exception as e:
        print(f"Error loading data: {e}")
        return None, None, None, None

# %%
X_Train, y_Train, X_Test, y_Test = load_train_test_data()
# Out:
# Mounted at /content/drive
# Google Drive mounted successfully.
# Data loaded successfully!
# X_train shape: (1801, 28)
# y_train shape: (1801, 1)
# X_test shape: (451, 28)
# y_test shape: (451, 1)

# %%
X_Train = X_Train.drop('Remission status _EOI', axis=1)
X_Test = X_Test.drop('Remission status _EOI', axis=1)

print(f"X_Train shape after dropping column: {X_Train.shape}")
print(f"X_Test shape after dropping column: {X_Test.shape}")
# Out:
# X_Train shape after dropping column: (1801, 27)
# X_Test shape after dropping column: (451, 27)

# %% [markdown]
# ## Data extract

# %%
file_path = "/content/Icicle Pre trial AI paper dataset_anonymised_April 2025.xlsx"
df_full = pd.read_excel(file_path)

# %%
print(df_full.columns)
# Out:
# Index(['Sl No', 'UPN_AI_dataset', 'Previous Treatment', 'Date of Birth',
#        'NCI Risk', 'Sex', 'Date of Diagnosis', 'Age', 'Lineage',
#        'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response',
#        'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics',
#        'Provisional risk', 'Date of Remission_EOI', 'Remission status _EOI',
#        'MRD Status_EOI', 'Final Risk ', 'Date of Completion of treatment',
#        'Relapsed', 'Date of Relapse', 'Time-point of Relapse ',
#        'Type of relapse', 'Site of Relapse ', 'Death', 'Date of Death ',
#        'Treatment death phase',
#        'Treatment abandonment/Disease progresssion/Off protocol',
#        'Date of Treatment abandonment/ Disease progresssion/Off protocol',
#        'Date of Last FU', 'Current status at Last Follow up '],
#       dtype='object')

# %%
def remove_columns(df, feature_set='normal'):

    # Define base leakage columns to always remove
    base_leakage_cols = [
        "Sl No",
        "UPN_AI_dataset",
        # All Date columns
        "Date of Birth", "Date of Diagnosis", "Date of Remission_EOI",
        "Date of Completion of treatment", "Date of Relapse",
        "Date of Death ", "Date of Treatment abandonment/ Disease progresssion/Off protocol",
        "Date of Last FU",
        # Relapse & outcome details
        "Time-point of Relapse ", "Type of relapse", "Site of Relapse ",
        "Death", "Treatment death phase",
        "Treatment abandonment/Disease progresssion/Off protocol",
        "Current status at Last Follow up "
    ]

    # Additional columns to remove for minimal feature set
    minimal_cols = [
        "Previous Treatment", "NCI Risk", "Lineage", "Bulky Disease",
        "CNS Disease", "Detail cytogenetics", "Provisional risk",
    ]

    # Combine columns based on feature_set parameter
    if feature_set == 'minimal':
        cols_to_remove = base_leakage_cols + minimal_cols
    else:  # 'normal' or any other value
        cols_to_remove = base_leakage_cols

    # Remove only columns that exist in the dataframe
    existing_cols_to_remove = [c for c in cols_to_remove if c in df.columns]
    df_clean = df.drop(columns=existing_cols_to_remove)

    return df_clean

# %%
# df_full_clean = remove_columns(df_full, feature_set='normal')
df_full_clean = df_full
print(df_full_clean.columns.tolist())
# Out:
# ['Sl No', 'UPN_AI_dataset', 'Previous Treatment', 'Date of Birth', 'NCI Risk', 'Sex', 'Date of Diagnosis', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Date of Remission_EOI', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ', 'Date of Completion of treatment', 'Relapsed', 'Date of Relapse', 'Time-point of Relapse ', 'Type of relapse', 'Site of Relapse ', 'Death', 'Date of Death ', 'Treatment death phase', 'Treatment abandonment/Disease progresssion/Off protocol', 'Date of Treatment abandonment/ Disease progresssion/Off protocol', 'Date of Last FU', 'Current status at Last Follow up ']

# %%
def clean_string_columns(df, columns_to_clean):
  existing_cols_to_clean = [col for col in columns_to_clean if col in df.columns]

  for col in existing_cols_to_clean:
      df[col] = df[col].astype("string").str.strip().str.lower()

  return df

# %%
df_full_strip = clean_string_columns(df_full_clean, ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ', 'Relapsed'])

# %%
file_path = "/content/X_test for clinician.xlsx"
df_cl = pd.read_excel(file_path)

# %%
print(df_cl.columns)
# Out:
# Index(['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
#        'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response',
#        'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics',
#        'Provisional risk', 'MRD Status_EOI', 'Final Risk ',
#        'Doctor Predictions'],
#       dtype='object')

# %%
df_cl_strip = clean_string_columns(df_cl, ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
       'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response',
       'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics',
       'Provisional risk', 'MRD Status_EOI', 'Final Risk ',
       'Doctor Predictions'])

# %%
print(df_cl_strip.shape)
# Out:
# (467, 15)

# %%
# Define key columns
# key_cols = ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
#             'Bulky Disease', 'Highest presenting WBC','Final Risk ']
key_cols = [
    'Previous Treatment',
    'NCI Risk',
    # 'Sex',
    'Age',
    'Lineage',
    'Bulky Disease',
    'Highest presenting WBC',
    'Prednisolone Response',
    'CNS Disease',
    'Cytogenetic groups ',
    'Detail cytogenetics',
    'Provisional risk',
    'MRD Status_EOI',
    'Final Risk '
    ]
# key_cols = ['Sex', 'Age','Highest presenting WBC']

df_cl_strip = df_cl_strip.reset_index().rename(columns={'index': 'clinical_idx'})


df_full_strip['Age'] = df_full_strip['Age'].astype(float).fillna(0).astype(int)
df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)
df_cl_strip['Age'] = df_cl_strip['Age'].astype(float).fillna(0).astype(int)
df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)

df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].round()
df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].round()

# Step 1: Inner merge on key columns to find matches
matches = pd.merge(df_full_strip,df_cl_strip, on=key_cols, how='right',indicator=True,suffixes=('_full', '_clinician'))

# Step 2: Count number of matching rows
print(f"Number of matching rows: {len(matches)}")

# Optional: preview some matching rows
# matches.head()
# Out:
# Number of matching rows: 473

# %%
# matches[matches["_merge"]=="right_only"]
matches["_merge"].value_counts()
# Out:
# _merge
# both          473
# left_only       0
# right_only      0
# Name: count, dtype: int64

# %%
matches
# Out:
#      Sl No UPN_AI_dataset Previous Treatment        Date of Birth  NCI Risk  \
# 0     2177     PT-AI_2177                 no  2012-02-26 00:00:00      high
# 1      396      PT-AI_396                 no        Not available  standard
# 2      790      PT-AI_790                yes        Not available  standard
# 3      466      PT-AI_466                 no        Not available  standard
# 4       62       PT-AI_62                 no  2005-11-07 00:00:00      high
# ..     ...            ...                ...                  ...       ...
# 468    982      PT-AI_982                 no        Not available  standard
# 469   1963     PT-AI_1963                 no        Not available      high
# 470   1368     PT-AI_1368                 no        Not available  standard
# 471   1893     PT-AI_1893                 no        Not available  standard
# 472   1117     PT-AI_1117                 no        Not available  standard
#
#     Sex_full Date of Diagnosis  Age Lineage Bulky Disease  \
# 0     female        2016-05-13    4       b            no
# 1       male        2017-05-30    2       b            no
# 2       male        2014-04-26    7       b           yes
# 3       male        2017-08-22    4       b           yes
# 4       male        2014-11-07    8       b            no
# ..       ...               ...  ...     ...           ...
# 468     male        2015-01-23    6       b           yes
# 469     male        2015-08-17   11       t           yes
# 470   female        2016-04-19    3       b           yes
# 471     male        2016-07-02    1       b            no
# 472     male        2015-06-17    2       b            no
#
#      Highest presenting WBC Prednisolone Response CNS Disease  \
# 0                    135000                  good          no
# 1                     20140                  good          no
# 2                      3830                  good          no
# 3                      6840                  good          no
# 4                     70700                  good         yes
# ..                      ...                   ...         ...
# 468                   30950                  good          no
# 469                    4500                  poor          no
# 470                   27000                  good          no
# 471                   12900                  good          no
# 472                    2000                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk  \
# 0         non-high risk             b-other     intermediate
# 1         non-high risk  high hyperdiploidy         standard
# 2                  <NA>                <NA>             high
# 3         non-high risk             b-other     intermediate
# 4         non-high risk             b-other             high
# ..                  ...                 ...              ...
# 468       non-high risk  high hyperdiploidy     intermediate
# 469        not required        not required                t
# 470       non-high risk             b-other     intermediate
# 471       non-high risk             b-other         standard
# 472       non-high risk  high hyperdiploidy         standard
#
#     Date of Remission_EOI Remission status _EOI MRD Status_EOI   Final Risk   \
# 0     2016-06-25 00:00:00          in remission           <NA>  intermediate
# 1     2017-07-11 00:00:00          in remission       negative      standard
# 2     2014-05-27 00:00:00          in remission       negative          high
# 3     2017-09-25 00:00:00          in remission       negative  intermediate
# 4     2014-12-13 00:00:00          in remission       negative          high
# ..                    ...                   ...            ...           ...
# 468   2015-02-23 00:00:00          in remission       negative  intermediate
# 469                     .                     .              .             .
# 470   2016-05-20 00:00:00          in remission       negative  intermediate
# 471   2016-08-16 00:00:00          in remission       negative      standard
# 472   2015-07-18 00:00:00          in remission       negative      standard
#
#     Date of Completion of treatment Relapsed      Date of Relapse  \
# 0               2019-04-02 00:00:00       no                    .
# 1                                 .       no                    .
# 2               2016-09-12 00:00:00       no                    .
# 3               2019-11-04 00:00:00       no                    .
# 4                                 .      yes  2015-10-05 00:00:00
# ..                              ...      ...                  ...
# 468             2017-03-30 00:00:00       no                    .
# 469                               .       no                    .
# 470             2018-06-30 00:00:00       no                    .
# 471             2019-01-15 00:00:00      yes  2021-04-07 00:00:00
# 472             2017-09-29 00:00:00       no                    .
#
#     Time-point of Relapse           Type of relapse Site of Relapse  Death  \
# 0                        .                        .                .    No
# 1                        .                        .                .    No
# 2                        .                        .                .    No
# 3                        .                        .                .    No
# 4               Very Early  Isolated extramedullary              CNS   Yes
# ..                     ...                      ...              ...   ...
# 468                      .                        .                .    No
# 469                      .                        .                .   Yes
# 470                      .                        .                .    No
# 471                   Late       Isolated medullary      Bone marrow    No
# 472                      .                        .                .    No
#
#           Date of Death  Treatment death phase  \
# 0                      .                     .
# 1                      .                     .
# 2                      .                     .
# 3                      .                     .
# 4    2015-12-22 00:00:00                     .
# ..                   ...                   ...
# 468                    .                     .
# 469  2015-12-24 00:00:00            Induction
# 470                    .                     .
# 471                    .                     .
# 472                    .                     .
#
#     Treatment abandonment/Disease progresssion/Off protocol  \
# 0                                                   No
# 1                                      Yes (Abandoned)
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 468                                                 No
# 469                                                 No
# 470                                                 No
# 471                                                 No
# 472                                                 No
#
#     Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 0                                                    .
# 1                                  2019-09-06 00:00:00
# 2                                                    .
# 3                                                    .
# 4                                                    .
# ..                                                 ...
# 468                                                  .
# 469                                                  .
# 470                                                  .
# 471                                                  .
# 472                                                  .
#
#     Date of Last FU Current status at Last Follow up   clinical_idx  \
# 0        2022-05-10                             Alive             0
# 1        2019-09-06                 Lost to follow up             1
# 2        2021-02-01                             Alive             2
# 3        2022-02-11                             Alive             3
# 4        2015-12-22                              Dead             4
# ..              ...                               ...           ...
# 468      2018-08-16                 Lost to follow up           462
# 469      2015-12-24                              Dead           463
# 470      2022-06-01                             Alive           464
# 471      2021-10-18                             Alive           465
# 472      2020-01-23                 Lost to follow up           466
#
#     Sex_clinician Doctor Predictions _merge
# 0          female               <NA>   both
# 1            male               <NA>   both
# 2            male               <NA>   both
# 3            male               <NA>   both
# 4            male               <NA>   both
# ..            ...                ...    ...
# 468          male               <NA>   both
# 469          male               <NA>   both
# 470        female               <NA>   both
# 471          male               <NA>   both
# 472          male               <NA>   both
#
# [473 rows x 37 columns]

# %%
# Group by key columns and count occurrences
grouped = matches.groupby(key_cols).size().reset_index(name='count')

# Filter for groups with count > 1
duplicates = grouped[grouped['count'] > 1]

# Merge back with the original 'matches' dataframe to show the actual duplicate rows
duplicate_rows = matches.merge(duplicates[key_cols], on=key_cols, how='inner')

print("Rows with more than one match based on key columns:")
duplicate_rows = duplicate_rows.sort_values(by='Highest presenting WBC')
pd.set_option('display.max_columns', None)

print(len(duplicate_rows))
# display(duplicate_rows)
# Out:
# Rows with more than one match based on key columns:
# 12

# %%
duplicate_rows
# Out:
#     Sl No UPN_AI_dataset Previous Treatment  Date of Birth  NCI Risk Sex_full  \
# 7    1310     PT-AI_1310                 no  Not available  standard     male
# 6    1107     PT-AI_1107                 no  Not available  standard     male
# 5    1077     PT-AI_1077                 no  Not available      high   female
# 4     672      PT-AI_672                 no  Not available      high   female
# 1    1911     PT-AI_1911                 no  Not available  standard     male
# 0     521      PT-AI_521                 no  Not available  standard     male
# 9    1911     PT-AI_1911                 no  Not available  standard     male
# 8     521      PT-AI_521                 no  Not available  standard     male
# 10    972      PT-AI_972                 no  Not available  standard     male
# 11   1746     PT-AI_1746                 no  Not available  standard     male
# 2     892      PT-AI_892                 no  Not available  standard     male
# 3    1244     PT-AI_1244                 no  Not available  standard   female
#
#    Date of Diagnosis  Age Lineage Bulky Disease  Highest presenting WBC  \
# 7         2016-02-19    5       b            no                    2000
# 6         2015-06-05    5       b            no                    2000
# 5         2015-05-09   12       b            no                    2000
# 4         2013-12-23   12       b            no                    2000
# 1         2016-08-13    2       b            no                    2510
# 0         2017-10-20    2       b            no                    2510
# 9         2016-08-13    2       b            no                    2510
# 8         2017-10-20    2       b            no                    2510
# 10        2015-01-07    4       b            no                    2700
# 11        2015-05-16    4       b            no                    2700
# 2         2013-06-09    7       b            no                    3800
# 3         2015-12-04    7       b            no                    3800
#
#    Prednisolone Response CNS Disease Cytogenetic groups  Detail cytogenetics  \
# 7                   good          no       non-high risk  high hyperdiploidy
# 6                   good          no       non-high risk  high hyperdiploidy
# 5                   good          no       non-high risk          etv6-runx1
# 4                   good          no       non-high risk          etv6-runx1
# 1                   good          no       non-high risk  high hyperdiploidy
# 0                   good          no       non-high risk  high hyperdiploidy
# 9                   good          no       non-high risk  high hyperdiploidy
# 8                   good          no       non-high risk  high hyperdiploidy
# 10                  good          no       non-high risk             b-other
# 11                  good          no       non-high risk             b-other
# 2                   good          no       non-high risk             b-other
# 3                   good          no       non-high risk             b-other
#
#    Provisional risk Date of Remission_EOI Remission status _EOI  \
# 7          standard   2016-03-21 00:00:00          in remission
# 6          standard   2015-07-06 00:00:00          in remission
# 5      intermediate   2015-06-09 00:00:00          in remission
# 4      intermediate   2014-01-23 00:00:00          in remission
# 1          standard   2016-09-19 00:00:00          in remission
# 0          standard   2017-12-04 00:00:00          in remission
# 9          standard   2016-09-19 00:00:00          in remission
# 8          standard   2017-12-04 00:00:00          in remission
# 10         standard   2015-02-07 00:00:00          in remission
# 11         standard   2015-06-24 00:00:00          in remission
# 2          standard   2013-07-10 00:00:00          in remission
# 3          standard   2016-01-04 00:00:00          in remission
#
#    MRD Status_EOI   Final Risk  Date of Completion of treatment Relapsed  \
# 7        negative      standard             2018-06-06 00:00:00       no
# 6        negative      standard             2017-09-17 00:00:00       no
# 5        negative  intermediate             2017-07-11 00:00:00       no
# 4        negative  intermediate             2016-02-28 00:00:00       no
# 1        negative      standard                               .      yes
# 0        negative      standard             2020-02-02 00:00:00       no
# 9        negative      standard                               .      yes
# 8        negative      standard             2020-02-02 00:00:00       no
# 10       negative      standard             2017-04-26 00:00:00       no
# 11       negative      standard             2017-10-25 00:00:00      yes
# 2        negative      standard             2015-09-19 00:00:00       no
# 3        negative      standard                             NaN       no
#
#         Date of Relapse Time-point of Relapse      Type of relapse  \
# 7                     .                      .                   .
# 6                     .                      .                   .
# 5                     .                      .                   .
# 4                     .                      .                   .
# 1   2017-05-26 00:00:00             Very Early  Isolated medullary
# 0                     .                      .                   .
# 9   2017-05-26 00:00:00             Very Early  Isolated medullary
# 8                     .                      .                   .
# 10                    .                      .                   .
# 11  2019-03-06 00:00:00                   Late            Combined
# 2                     .                      .                   .
# 3                     .                      .                   .
#
#       Site of Relapse  Death       Date of Death  Treatment death phase  \
# 7                    .    No                    .                     .
# 6                    .    No                    .                     .
# 5                    .    No                    .                     .
# 4                    .    No                    .                     .
# 1          Bone marrow   Yes  2018-01-16 00:00:00                     .
# 0                    .    No                    .                     .
# 9          Bone marrow   Yes  2018-01-16 00:00:00                     .
# 8                    .    No                    .                     .
# 10                   .    No                    .                     .
# 11  Bone marrow+Testes    No                    .                     .
# 2                    .    No                    .                     .
# 3                    .    No                    .                     .
#
#    Treatment abandonment/Disease progresssion/Off protocol  \
# 7                                                  No
# 6                                                  No
# 5                                                  No
# 4                                                  No
# 1                                                  No
# 0                                                  No
# 9                                                  No
# 8                                                  No
# 10                                                 No
# 11                                                 No
# 2                                                  No
# 3                                                  No
#
#    Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 7                                                   .
# 6                                                   .
# 5                                                   .
# 4                                                   .
# 1                                                   .
# 0                                                   .
# 9                                                   .
# 8                                                   .
# 10                                                  .
# 11                                                  .
# 2                                                   .
# 3                                                   .
#
#    Date of Last FU Current status at Last Follow up   clinical_idx  \
# 7       2019-09-18                 Lost to follow up           402
# 6       2021-09-24                             Alive           402
# 5       2022-04-06                             Alive           306
# 4       2018-07-19                 Lost to follow up           306
# 1       2018-01-16                              Dead             5
# 0       2020-05-18                 Lost to follow up             5
# 9       2018-01-16                              Dead           420
# 8       2020-05-18                 Lost to follow up           420
# 10      2022-03-24                             Alive           430
# 11      2021-11-20                             Alive           430
# 2       2022-05-23                             Alive           257
# 3       2016-04-01                 Lost to follow up           257
#
#    Sex_clinician Doctor Predictions _merge
# 7           male               <NA>   both
# 6           male               <NA>   both
# 5         female               <NA>   both
# 4         female               <NA>   both
# 1           male               <NA>   both
# 0           male               <NA>   both
# 9           male               <NA>   both
# 8           male               <NA>   both
# 10          male               <NA>   both
# 11          male               <NA>   both
# 2         female               <NA>   both
# 3         female               <NA>   both

# %%
# Check for duplicate rows within df_cl_strip
duplicates_within_cl_strip = df_cl_strip[df_cl_strip.duplicated()]

if not duplicates_within_cl_strip.empty:
    print("Duplicate rows found within df_cl_strip:")
    display(duplicates_within_cl_strip)
else:
    print("No duplicate rows found within df_cl_strip.")
# Out:
# No duplicate rows found within df_cl_strip.

# %%
df_cl_strip
# Out:
#      clinical_idx Previous Treatment  NCI Risk     Sex  Age Lineage  \
# 0               0                 no      high  female    4       b
# 1               1                 no  standard    male    2       b
# 2               2                yes  standard    male    7       b
# 3               3                 no  standard    male    4       b
# 4               4                 no      high    male    8       b
# ..            ...                ...       ...     ...  ...     ...
# 462           462                 no  standard    male    6       b
# 463           463                 no      high    male   11       t
# 464           464                 no  standard  female    3       b
# 465           465                 no  standard    male    1       b
# 466           466                 no  standard    male    2       b
#
#     Bulky Disease  Highest presenting WBC Prednisolone Response CNS Disease  \
# 0              no                  135000                  good          no
# 1              no                   20140                  good          no
# 2             yes                    3830                  good          no
# 3             yes                    6840                  good          no
# 4              no                   70700                  good         yes
# ..            ...                     ...                   ...         ...
# 462           yes                   30950                  good          no
# 463           yes                    4500                  poor          no
# 464           yes                   27000                  good          no
# 465            no                   12900                  good          no
# 466            no                    2000                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk MRD Status_EOI  \
# 0         non-high risk             b-other     intermediate           <NA>
# 1         non-high risk  high hyperdiploidy         standard       negative
# 2                  <NA>                <NA>             high       negative
# 3         non-high risk             b-other     intermediate       negative
# 4         non-high risk             b-other             high       negative
# ..                  ...                 ...              ...            ...
# 462       non-high risk  high hyperdiploidy     intermediate       negative
# 463        not required        not required                t              .
# 464       non-high risk             b-other     intermediate       negative
# 465       non-high risk             b-other         standard       negative
# 466       non-high risk  high hyperdiploidy         standard       negative
#
#       Final Risk  Doctor Predictions
# 0    intermediate               <NA>
# 1        standard               <NA>
# 2            high               <NA>
# 3    intermediate               <NA>
# 4            high               <NA>
# ..            ...                ...
# 462  intermediate               <NA>
# 463             .               <NA>
# 464  intermediate               <NA>
# 465      standard               <NA>
# 466      standard               <NA>
#
# [467 rows x 16 columns]

# %%
# Find duplicate clinical_idx within df_cl_strip
duplicate_clinical_idx = df_cl_strip[df_cl_strip['clinical_idx'].duplicated(keep=False)]

if not duplicate_clinical_idx.empty:
    print("Duplicate clinical_idx found within df_cl_strip:")
    display(duplicate_clinical_idx)
else:
    print("No duplicate clinical_idx found within df_cl_strip.")
# Out:
# No duplicate clinical_idx found within df_cl_strip.

# %%
# Get the clinical_idx values from the duplicate_rows
indices_to_remove = duplicate_rows['clinical_idx'].unique().tolist()

## Remove rows from df_cl_strip where clinical_idx is in the indices_to_remove list
df_cl_strip = df_cl_strip[~df_cl_strip['clinical_idx'].isin(indices_to_remove)]

print(indices_to_remove)

# # Remove rows from df_cl_strip where clinical_idx is in the indices_to_remove list
# df_cl_strip = df_cl_strip[~df_cl_strip['clinical_idx'].isin(indices_to_remove)]

# print(f"Removed {len(indices_to_remove)} duplicate rows from df_cl_strip.")

df_cl_strip[df_cl_strip['clinical_idx'] == 402]
# Out:
# [402, 306, 5, 420, 430, 257]
# Empty DataFrame
# Columns: [clinical_idx, Previous Treatment, NCI Risk, Sex, Age, Lineage, Bulky Disease, Highest presenting WBC, Prednisolone Response, CNS Disease, Cytogenetic groups , Detail cytogenetics, Provisional risk, MRD Status_EOI, Final Risk , Doctor Predictions]
# Index: []

# %%
df_cl_strip[df_cl_strip['clinical_idx'] == 257]
# Out:
# Empty DataFrame
# Columns: [clinical_idx, Previous Treatment, NCI Risk, Sex, Age, Lineage, Bulky Disease, Highest presenting WBC, Prednisolone Response, CNS Disease, Cytogenetic groups , Detail cytogenetics, Provisional risk, MRD Status_EOI, Final Risk , Doctor Predictions]
# Index: []

# %%
print(df_cl_strip.shape)
# Out:
# (461, 16)

# %%
# Define key columns
# key_cols = ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
#             'Bulky Disease', 'Highest presenting WBC','Final Risk ']
key_cols = [
    'Previous Treatment',
    'NCI Risk',
    # 'Sex',
    'Age',
    'Lineage',
    'Bulky Disease',
    'Highest presenting WBC',
    'Prednisolone Response',
    'CNS Disease',
    'Cytogenetic groups ',
    'Detail cytogenetics',
    'Provisional risk',
    'MRD Status_EOI',
    'Final Risk '
    ]
# key_cols = ['Sex', 'Age','Highest presenting WBC']

# df_cl_strip = df_cl_strip.reset_index().rename(columns={'index': 'clinical_idx'})


# df_full_strip['Age'] = df_full_strip['Age'].astype(float).fillna(0).astype(int)
# df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)
# df_cl_strip['Age'] = df_cl_strip['Age'].astype(float).fillna(0).astype(int)
# df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)

# df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].round()
# df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].round()

# Step 1: Inner merge on key columns to find matches
matches1 = pd.merge(df_full_strip,df_cl_strip, on=key_cols, how='right',indicator=True,suffixes=('_full', '_clinician'))

# Step 2: Count number of matching rows
print(f"Number of matching rows: {len(matches1)}")

# Optional: preview some matching rows
# matches.head()
# Out:
# Number of matching rows: 461

# %%
# Select 'clinical_idx' and 'Sl No' from matches1 for merging
sl_no_data = matches1[['clinical_idx', 'Sl No']].copy()

# Merge df_cl_strip with sl_no_data on clinical_idx
df_cl_strip = pd.merge(df_cl_strip, sl_no_data, on='clinical_idx', how='left')

print("Sl No column added to df_cl_strip.")
print(f"New shape of df_cl_strip: {df_cl_strip.shape}")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /tmp/ipython-input-741727361.py in <cell line: 0>()
#       3
#       4 # Merge df_cl_strip with sl_no_data on clinical_idx
# ----> 5 df_cl_strip = pd.merge(df_cl_strip, sl_no_data, on='clinical_idx', how='left')
#       6
#       7 print("Sl No column added to df_cl_strip.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     182             validate=validate,
#     183         )
# --> 184         return op.get_result(copy=copy)
#     185
#     186
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     886         join_index, left_indexer, right_indexer = self._get_join_info()
#     887
# --> 888         result = self._reindex_and_concat(
#     889             join_index, left_indexer, right_indexer, copy=copy
#     890         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     838         right = self.right[:]
#     839
# --> 840         llabels, rlabels = _items_overlap_with_suffix(
#     841             self.left._info_axis, self.right._info_axis, self.suffixes
#     842         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2755         dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756     if dups:
# -> 2757         raise MergeError(
#    2758             f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759             f"not allowed.",
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'Sl No_x'} is not allowed.

# %%
# Reorder columns to put 'Sl No' as the first column
current_cols = df_cl_strip.columns.tolist()
# Remove the duplicate 'Sl No' column if it exists before reordering
if 'Sl No_x' in current_cols:
    current_cols.remove('Sl No_x')
if 'Sl No_y' in current_cols:
    current_cols.remove('Sl No_y')
if 'Sl No' in current_cols:
    current_cols.remove('Sl No')
new_cols = ['Sl No'] + current_cols
df_cl_strip = df_cl_strip[new_cols]

print("Sl No column reordered to be the first column.")
print(f"New shape of df_cl_strip: {df_cl_strip.shape}")
# Out:
# Sl No column reordered to be the first column.
# New shape of df_cl_strip: (461, 17)

# %%
# Identify columns missing in df_cl_strip compared to df_full_strip (excluding 'Sl No')
missing_cols = [col for col in df_full_strip.columns if col not in df_cl_strip.columns and col != 'Sl No']

# Select 'Sl No' and the missing columns from df_full_strip
cols_to_merge_from_full = ['Sl No'] + missing_cols

# Merge df_cl_strip with the selected columns from df_full_strip on 'Sl No'
# Using a left merge to keep all rows from df_cl_strip
df_cl_strip = pd.merge(df_cl_strip, df_full_strip[cols_to_merge_from_full], on='Sl No', how='left')

print("Missing columns from df_full_strip appended to df_cl_strip.")
print(f"New shape of df_cl_strip: {df_cl_strip.shape}")
print(f"Columns added: {missing_cols}")
# Out:
# Missing columns from df_full_strip appended to df_cl_strip.
# New shape of df_cl_strip: (461, 35)
# Columns added: ['UPN_AI_dataset', 'Date of Birth', 'Date of Diagnosis', 'Date of Remission_EOI', 'Remission status _EOI', 'Date of Completion of treatment', 'Relapsed', 'Date of Relapse', 'Time-point of Relapse ', 'Type of relapse', 'Site of Relapse ', 'Death', 'Date of Death ', 'Treatment death phase', 'Treatment abandonment/Disease progresssion/Off protocol', 'Date of Treatment abandonment/ Disease progresssion/Off protocol', 'Date of Last FU', 'Current status at Last Follow up ']

# %%
df_cl_strip
# Out:
#      Sl No  clinical_idx Previous Treatment  NCI Risk     Sex  Age Lineage  \
# 0     2177             0                 no      high  female    4       b
# 1      396             1                 no  standard    male    2       b
# 2      790             2                yes  standard    male    7       b
# 3      466             3                 no  standard    male    4       b
# 4       62             4                 no      high    male    8       b
# ..     ...           ...                ...       ...     ...  ...     ...
# 456    982           462                 no  standard    male    6       b
# 457   1963           463                 no      high    male   11       t
# 458   1368           464                 no  standard  female    3       b
# 459   1893           465                 no  standard    male    1       b
# 460   1117           466                 no  standard    male    2       b
#
#     Bulky Disease  Highest presenting WBC Prednisolone Response CNS Disease  \
# 0              no                  135000                  good          no
# 1              no                   20140                  good          no
# 2             yes                    3830                  good          no
# 3             yes                    6840                  good          no
# 4              no                   70700                  good         yes
# ..            ...                     ...                   ...         ...
# 456           yes                   30950                  good          no
# 457           yes                    4500                  poor          no
# 458           yes                   27000                  good          no
# 459            no                   12900                  good          no
# 460            no                    2000                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk MRD Status_EOI  \
# 0         non-high risk             b-other     intermediate           <NA>
# 1         non-high risk  high hyperdiploidy         standard       negative
# 2                  <NA>                <NA>             high       negative
# 3         non-high risk             b-other     intermediate       negative
# 4         non-high risk             b-other             high       negative
# ..                  ...                 ...              ...            ...
# 456       non-high risk  high hyperdiploidy     intermediate       negative
# 457        not required        not required                t              .
# 458       non-high risk             b-other     intermediate       negative
# 459       non-high risk             b-other         standard       negative
# 460       non-high risk  high hyperdiploidy         standard       negative
#
#       Final Risk  Doctor Predictions UPN_AI_dataset        Date of Birth  \
# 0    intermediate               <NA>     PT-AI_2177  2012-02-26 00:00:00
# 1        standard               <NA>      PT-AI_396        Not available
# 2            high               <NA>      PT-AI_790        Not available
# 3    intermediate               <NA>      PT-AI_466        Not available
# 4            high               <NA>       PT-AI_62  2005-11-07 00:00:00
# ..            ...                ...            ...                  ...
# 456  intermediate               <NA>      PT-AI_982        Not available
# 457             .               <NA>     PT-AI_1963        Not available
# 458  intermediate               <NA>     PT-AI_1368        Not available
# 459      standard               <NA>     PT-AI_1893        Not available
# 460      standard               <NA>     PT-AI_1117        Not available
#
#     Date of Diagnosis Date of Remission_EOI Remission status _EOI  \
# 0          2016-05-13   2016-06-25 00:00:00          in remission
# 1          2017-05-30   2017-07-11 00:00:00          in remission
# 2          2014-04-26   2014-05-27 00:00:00          in remission
# 3          2017-08-22   2017-09-25 00:00:00          in remission
# 4          2014-11-07   2014-12-13 00:00:00          in remission
# ..                ...                   ...                   ...
# 456        2015-01-23   2015-02-23 00:00:00          in remission
# 457        2015-08-17                     .                     .
# 458        2016-04-19   2016-05-20 00:00:00          in remission
# 459        2016-07-02   2016-08-16 00:00:00          in remission
# 460        2015-06-17   2015-07-18 00:00:00          in remission
#
#     Date of Completion of treatment Relapsed      Date of Relapse  \
# 0               2019-04-02 00:00:00       no                    .
# 1                                 .       no                    .
# 2               2016-09-12 00:00:00       no                    .
# 3               2019-11-04 00:00:00       no                    .
# 4                                 .      yes  2015-10-05 00:00:00
# ..                              ...      ...                  ...
# 456             2017-03-30 00:00:00       no                    .
# 457                               .       no                    .
# 458             2018-06-30 00:00:00       no                    .
# 459             2019-01-15 00:00:00      yes  2021-04-07 00:00:00
# 460             2017-09-29 00:00:00       no                    .
#
#     Time-point of Relapse           Type of relapse Site of Relapse  Death  \
# 0                        .                        .                .    No
# 1                        .                        .                .    No
# 2                        .                        .                .    No
# 3                        .                        .                .    No
# 4               Very Early  Isolated extramedullary              CNS   Yes
# ..                     ...                      ...              ...   ...
# 456                      .                        .                .    No
# 457                      .                        .                .   Yes
# 458                      .                        .                .    No
# 459                   Late       Isolated medullary      Bone marrow    No
# 460                      .                        .                .    No
#
#           Date of Death  Treatment death phase  \
# 0                      .                     .
# 1                      .                     .
# 2                      .                     .
# 3                      .                     .
# 4    2015-12-22 00:00:00                     .
# ..                   ...                   ...
# 456                    .                     .
# 457  2015-12-24 00:00:00            Induction
# 458                    .                     .
# 459                    .                     .
# 460                    .                     .
#
#     Treatment abandonment/Disease progresssion/Off protocol  \
# 0                                                   No
# 1                                      Yes (Abandoned)
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 456                                                 No
# 457                                                 No
# 458                                                 No
# 459                                                 No
# 460                                                 No
#
#     Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 0                                                    .
# 1                                  2019-09-06 00:00:00
# 2                                                    .
# 3                                                    .
# 4                                                    .
# ..                                                 ...
# 456                                                  .
# 457                                                  .
# 458                                                  .
# 459                                                  .
# 460                                                  .
#
#     Date of Last FU Current status at Last Follow up
# 0        2022-05-10                             Alive
# 1        2019-09-06                 Lost to follow up
# 2        2021-02-01                             Alive
# 3        2022-02-11                             Alive
# 4        2015-12-22                              Dead
# ..              ...                               ...
# 456      2018-08-16                 Lost to follow up
# 457      2015-12-24                              Dead
# 458      2022-06-01                             Alive
# 459      2021-10-18                             Alive
# 460      2020-01-23                 Lost to follow up
#
# [461 rows x 35 columns]

# %%
# Remove 'clinical_idx' and 'Doctor Predictions' columns from df_cl_strip
df_test = df_cl_strip.drop(columns=['clinical_idx', 'Doctor Predictions'])

print("Removed 'clinical_idx' and 'Doctor Predictions' columns from df_cl_strip.")
print(f"New shape of df_test: {df_test.shape}")
# Out:
# Removed 'clinical_idx' and 'Doctor Predictions' columns from df_cl_strip.
# New shape of df_test: (461, 33)

# %%
not_in_remission_count = df_test[df_test['Remission status _EOI'] == 'not in remission'].shape[0]
print(f"Number of entries in df_test with 'not in remission' in 'Remission status _EOI': {not_in_remission_count}")
# Out:
# Number of entries in df_test with 'not in remission' in 'Remission status _EOI': 14

# %%
# Get the list of 'Sl No' values from df_cl_strip
sl_nos_to_remove = df_test['Sl No'].tolist()

# Remove rows from df_full_strip where 'Sl No' is in the list of Sl Nos from df_cl_strip
df_full_strip_remaining = df_full_strip[~df_full_strip['Sl No'].isin(sl_nos_to_remove)].copy()

print(f"Removed {len(sl_nos_to_remove)} rows from df_full_strip based on Sl No in df_test.")
print(f"New shape of df_full_strip_remaining: {df_full_strip_remaining.shape}")
# Out:
# Removed 461 rows from df_full_strip based on Sl No in df_test.
# New shape of df_full_strip_remaining: (1870, 33)

# %%
not_in_remission_count1 = df_full_strip[df_full_strip['Remission status _EOI'] == 'not in remission'].shape[0]
print(f"Number of entries in df_test with 'not in remission' in 'Remission status _EOI': {not_in_remission_count1}")
# Out:
# Number of entries in df_test with 'not in remission' in 'Remission status _EOI': 79

# %%
not_in_remission_count2 = df_full_strip_remaining[df_full_strip_remaining['Remission status _EOI'] == 'not in remission'].shape[0]
print(f"Number of entries in df_test with 'not in remission' in 'Remission status _EOI': {not_in_remission_count2}")
# Out:
# Number of entries in df_test with 'not in remission' in 'Remission status _EOI': 65

# %%
df_train = df_full_strip_remaining

# %%
# Define the folder path in Google Drive
folder_path = '/content/drive/MyDrive/NIR dataset/'

# Create the directory if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Define the file paths for df_train and df_test
save_path_train = folder_path + 'df_train.xlsx'
save_path_test = folder_path + 'df_test.xlsx'

# Save df_train to an Excel file
df_train.to_excel(save_path_train, index=False)
print(f"df_train saved successfully to {save_path_train}")

# Save df_test to an Excel file
df_test.to_excel(save_path_test, index=False)
print(f"df_test saved successfully to {save_path_test}")
# Out:
# df_train saved successfully to /content/drive/MyDrive/NIR dataset/df_train.xlsx
# df_test saved successfully to /content/drive/MyDrive/NIR dataset/df_test.xlsx

# %%
#####################################                                   XXX                             ##############################################

# %%
matches1[matches1['Remission status _EOI']=="not in remission"][["Sl No","clinical_idx"]]["Sl No"].to_list()
# Out:
# [1514, 450, 530, 1973, 2284, 298, 1960, 1595, 2142, 291, 1631, 2230, 60, 2294]

# %%
matches1
# Out:
#      Sl No UPN_AI_dataset Previous Treatment        Date of Birth  NCI Risk  \
# 0     2177     PT-AI_2177                 no  2012-02-26 00:00:00      high
# 1      396      PT-AI_396                 no        Not available  standard
# 2      790      PT-AI_790                yes        Not available  standard
# 3      466      PT-AI_466                 no        Not available  standard
# 4       62       PT-AI_62                 no  2005-11-07 00:00:00      high
# ..     ...            ...                ...                  ...       ...
# 456    982      PT-AI_982                 no        Not available  standard
# 457   1963     PT-AI_1963                 no        Not available      high
# 458   1368     PT-AI_1368                 no        Not available  standard
# 459   1893     PT-AI_1893                 no        Not available  standard
# 460   1117     PT-AI_1117                 no        Not available  standard
#
#     Sex_full Date of Diagnosis  Age Lineage Bulky Disease  \
# 0     female        2016-05-13    4       b            no
# 1       male        2017-05-30    2       b            no
# 2       male        2014-04-26    7       b           yes
# 3       male        2017-08-22    4       b           yes
# 4       male        2014-11-07    8       b            no
# ..       ...               ...  ...     ...           ...
# 456     male        2015-01-23    6       b           yes
# 457     male        2015-08-17   11       t           yes
# 458   female        2016-04-19    3       b           yes
# 459     male        2016-07-02    1       b            no
# 460     male        2015-06-17    2       b            no
#
#      Highest presenting WBC Prednisolone Response CNS Disease  \
# 0                    135000                  good          no
# 1                     20140                  good          no
# 2                      3830                  good          no
# 3                      6840                  good          no
# 4                     70700                  good         yes
# ..                      ...                   ...         ...
# 456                   30950                  good          no
# 457                    4500                  poor          no
# 458                   27000                  good          no
# 459                   12900                  good          no
# 460                    2000                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk  \
# 0         non-high risk             b-other     intermediate
# 1         non-high risk  high hyperdiploidy         standard
# 2                  <NA>                <NA>             high
# 3         non-high risk             b-other     intermediate
# 4         non-high risk             b-other             high
# ..                  ...                 ...              ...
# 456       non-high risk  high hyperdiploidy     intermediate
# 457        not required        not required                t
# 458       non-high risk             b-other     intermediate
# 459       non-high risk             b-other         standard
# 460       non-high risk  high hyperdiploidy         standard
#
#     Date of Remission_EOI Remission status _EOI MRD Status_EOI   Final Risk   \
# 0     2016-06-25 00:00:00          in remission           <NA>  intermediate
# 1     2017-07-11 00:00:00          in remission       negative      standard
# 2     2014-05-27 00:00:00          in remission       negative          high
# 3     2017-09-25 00:00:00          in remission       negative  intermediate
# 4     2014-12-13 00:00:00          in remission       negative          high
# ..                    ...                   ...            ...           ...
# 456   2015-02-23 00:00:00          in remission       negative  intermediate
# 457                     .                     .              .             .
# 458   2016-05-20 00:00:00          in remission       negative  intermediate
# 459   2016-08-16 00:00:00          in remission       negative      standard
# 460   2015-07-18 00:00:00          in remission       negative      standard
#
#     Date of Completion of treatment Relapsed      Date of Relapse  \
# 0               2019-04-02 00:00:00       no                    .
# 1                                 .       no                    .
# 2               2016-09-12 00:00:00       no                    .
# 3               2019-11-04 00:00:00       no                    .
# 4                                 .      yes  2015-10-05 00:00:00
# ..                              ...      ...                  ...
# 456             2017-03-30 00:00:00       no                    .
# 457                               .       no                    .
# 458             2018-06-30 00:00:00       no                    .
# 459             2019-01-15 00:00:00      yes  2021-04-07 00:00:00
# 460             2017-09-29 00:00:00       no                    .
#
#     Time-point of Relapse           Type of relapse Site of Relapse  Death  \
# 0                        .                        .                .    No
# 1                        .                        .                .    No
# 2                        .                        .                .    No
# 3                        .                        .                .    No
# 4               Very Early  Isolated extramedullary              CNS   Yes
# ..                     ...                      ...              ...   ...
# 456                      .                        .                .    No
# 457                      .                        .                .   Yes
# 458                      .                        .                .    No
# 459                   Late       Isolated medullary      Bone marrow    No
# 460                      .                        .                .    No
#
#           Date of Death  Treatment death phase  \
# 0                      .                     .
# 1                      .                     .
# 2                      .                     .
# 3                      .                     .
# 4    2015-12-22 00:00:00                     .
# ..                   ...                   ...
# 456                    .                     .
# 457  2015-12-24 00:00:00            Induction
# 458                    .                     .
# 459                    .                     .
# 460                    .                     .
#
#     Treatment abandonment/Disease progresssion/Off protocol  \
# 0                                                   No
# 1                                      Yes (Abandoned)
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 456                                                 No
# 457                                                 No
# 458                                                 No
# 459                                                 No
# 460                                                 No
#
#     Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 0                                                    .
# 1                                  2019-09-06 00:00:00
# 2                                                    .
# 3                                                    .
# 4                                                    .
# ..                                                 ...
# 456                                                  .
# 457                                                  .
# 458                                                  .
# 459                                                  .
# 460                                                  .
#
#     Date of Last FU Current status at Last Follow up   clinical_idx  \
# 0        2022-05-10                             Alive             0
# 1        2019-09-06                 Lost to follow up             1
# 2        2021-02-01                             Alive             2
# 3        2022-02-11                             Alive             3
# 4        2015-12-22                              Dead             4
# ..              ...                               ...           ...
# 456      2018-08-16                 Lost to follow up           462
# 457      2015-12-24                              Dead           463
# 458      2022-06-01                             Alive           464
# 459      2021-10-18                             Alive           465
# 460      2020-01-23                 Lost to follow up           466
#
#     Sex_clinician Doctor Predictions _merge
# 0          female               <NA>   both
# 1            male               <NA>   both
# 2            male               <NA>   both
# 3            male               <NA>   both
# 4            male               <NA>   both
# ..            ...                ...    ...
# 456          male               <NA>   both
# 457          male               <NA>   both
# 458        female               <NA>   both
# 459          male               <NA>   both
# 460          male               <NA>   both
#
# [461 rows x 37 columns]

# %%
# Count entries with 'not in remission' in 'Remission status _EOI'
not_in_remission_count = matches1[matches1['Remission status _EOI'] == 'not in remission'].shape[0]

print(f"Number of entries in matches1 with 'not in remission' in 'Remission status _EOI': {not_in_remission_count}")
# Out:
# Number of entries in matches1 with 'not in remission' in 'Remission status _EOI': 14

# %%
# Get the clinical_idx for entries with 'not in remission' in matches1
not_in_remission_indices = matches1[matches1['Remission status _EOI'] == 'not in remission']['clinical_idx'].tolist()

print(not_in_remission_indices)
# Out:
# [102, 123, 182, 196, 216, 228, 232, 239, 291, 294, 393, 405, 416, 425]

# %%
# Print the matches1 entries from the not_in_remission_indices
display(matches1[matches1['clinical_idx'].isin(not_in_remission_indices)])
# Out:
#      Sl No UPN_AI_dataset Previous Treatment        Date of Birth  NCI Risk  \
# 101   1514     PT-AI_1514                yes        Not available  standard
# 122    450      PT-AI_450                 no        Not available  standard
# 181    530      PT-AI_530                 no        Not available      high
# 195   1973     PT-AI_1973                 no        Not available      high
# 215   2284     PT-AI_2284                 no  2006-06-03 00:00:00  standard
# 227    298      PT-AI_298                yes        Not available  standard
# 231   1960     PT-AI_1960                 no        Not available      high
# 238   1595     PT-AI_1595                 no        Not available  standard
# 289   2142     PT-AI_2142                 no  2005-03-06 00:00:00      high
# 292    291      PT-AI_291                 no        Not available  standard
# 390   1631     PT-AI_1631                yes        Not available      high
# 401   2230     PT-AI_2230                 no  2011-08-10 00:00:00      high
# 412     60       PT-AI_60                 no  2012-12-24 00:00:00  standard
# 420   2294     PT-AI_2294                 no  2011-11-14 00:00:00  standard
#
#     Sex_full Date of Diagnosis  Age Lineage Bulky Disease  \
# 101     male        2016-09-21    3       b            no
# 122   female        2017-08-03    6       b            no
# 181     male        2017-10-31   13       b            no
# 195   female        2015-12-16    5       b            no
# 215     male        2015-03-04    8       b           yes
# 227     male        2017-02-27    3       b            no
# 231   female        2015-07-29   13       b           yes
# 238   female        2016-12-17    9       b            no
# 289     male        2015-02-07    9       t            no
# 292   female        2017-02-27    7       b            no
# 390     male        2014-05-12   17       b            no
# 401   female        2016-10-25    5       t           yes
# 412     male        2014-10-14    1       b            no
# 420     male        2017-03-22    5       b            no
#
#      Highest presenting WBC Prednisolone Response CNS Disease  \
# 101                   18760                  good          no
# 122                   30100                  good          no
# 181                   18870                  poor          no
# 195                  280000                  <NA>          no
# 215                    1100                  good          no
# 227                    2970                  good          no
# 231                  850000                  <NA>          no
# 238                    3730                  good          no
# 289                  420000                  poor          no
# 292                    2970                  good          no
# 390                    1600                  good          no
# 401                  400000                  poor          no
# 412                   10500                  good          no
# 420                    7500                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk  \
# 101       non-high risk             b-other             high
# 122       non-high risk             b-other         standard
# 181       non-high risk  high hyperdiploidy             high
# 195       non-high risk                <NA>             high
# 215       non-high risk  high hyperdiploidy     intermediate
# 227           high risk    kmt2a rearranged             high
# 231       non-high risk                <NA>             high
# 238       non-high risk             b-other         standard
# 289        not required        not required                t
# 292       non-high risk  high hyperdiploidy         standard
# 390       non-high risk             b-other             high
# 401        not required        not required                t
# 412       non-high risk  high hyperdiploidy         standard
# 420       non-high risk  high hyperdiploidy         standard
#
#     Date of Remission_EOI Remission status _EOI MRD Status_EOI Final Risk   \
# 101   2016-11-08 00:00:00      not in remission       positive        high
# 122   2017-09-08 00:00:00      not in remission       positive        high
# 181   2017-12-13 00:00:00      not in remission       positive        high
# 195   2016-01-22 00:00:00      not in remission       positive        high
# 215   2015-04-21 00:00:00      not in remission       positive        high
# 227   2017-04-10 00:00:00      not in remission       positive        high
# 231   2015-10-01 00:00:00      not in remission       positive        high
# 238   2017-01-30 00:00:00      not in remission       positive        high
# 289   2015-03-10 00:00:00      not in remission   not required           .
# 292   2017-04-11 00:00:00      not in remission       positive        high
# 390   2014-07-25 00:00:00      not in remission       positive        high
# 401   2016-11-27 00:00:00      not in remission   not required           t
# 412   2014-11-21 00:00:00      not in remission       positive        high
# 420   2017-04-26 00:00:00      not in remission       positive        high
#
#     Date of Completion of treatment Relapsed Date of Relapse  \
# 101                             NaN       no               .
# 122                               .       no               .
# 181                               .       no               .
# 195             2018-12-20 00:00:00       no               .
# 215             2017-10-26 00:00:00       no               .
# 227                               .       no               .
# 231                               .       no               .
# 238                               .       no               .
# 289                               .       no               .
# 292             2019-07-16 00:00:00       no               .
# 390                               .       no               .
# 401                               .       no               .
# 412             2017-04-13 00:00:00       no               .
# 420             2019-11-06 00:00:00       no               .
#
#     Time-point of Relapse  Type of relapse Site of Relapse  Death  \
# 101                      .               .                .    No
# 122                      .               .                .   Yes
# 181                      .               .                .   Yes
# 195                      .               .                .    No
# 215                      .               .                .    No
# 227                      .               .                .   Yes
# 231                      .               .                .    No
# 238                      .               .                .    No
# 289                      .               .                .   Yes
# 292                      .               .                .    No
# 390                      .               .                .    No
# 401                      .               .                .   Yes
# 412                      .               .                .    No
# 420                      .               .                .    No
#
#           Date of Death  Treatment death phase  \
# 101                    .                     .
# 122  2018-08-13 00:00:00                     .
# 181  2019-07-31 00:00:00                     .
# 195                    .                     .
# 215                    .                     .
# 227  2017-06-30 00:00:00                     .
# 231                    .                     .
# 238                    .                     .
# 289  2015-07-02 00:00:00                     .
# 292                    .                     .
# 390                    .                     .
# 401  2018-09-26 00:00:00                     .
# 412                    .                     .
# 420                    .                     .
#
#     Treatment abandonment/Disease progresssion/Off protocol  \
# 101                                                 No
# 122                                 Yes (Off protocol)
# 181                                 Yes (Off protocol)
# 195                                                 No
# 215                                                 No
# 227                                                 No
# 231                                 Yes (Off protocol)
# 238                                 Yes (Off protocol)
# 289                                 Yes (Off protocol)
# 292                                                 No
# 390                                 Yes (Off protocol)
# 401                                                 No
# 412                                                 No
# 420                                                 No
#
#     Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 101                                                  .
# 122                                2017-09-08 00:00:00
# 181                                2017-12-13 00:00:00
# 195                                                  .
# 215                                                  .
# 227                                                  .
# 231                                2015-10-01 00:00:00
# 238                                2017-01-30 00:00:00
# 289                                2015-03-10 00:00:00
# 292                                                  .
# 390                                2014-07-25 00:00:00
# 401                                                  .
# 412                                                  .
# 420                                                  .
#
#     Date of Last FU Current status at Last Follow up   clinical_idx  \
# 101      2022-02-18                             Alive           102
# 122      2018-08-13                              Dead           123
# 181      2019-07-31                              Dead           182
# 195      2020-06-13                 Lost to follow up           196
# 215      2022-05-21                             Alive           216
# 227      2017-06-30                              Dead           228
# 231      2015-10-05                 Lost to follow up           232
# 238      2019-02-28                 Lost to follow up           239
# 289      2015-07-02                              Dead           291
# 292      2022-02-15                             Alive           294
# 390      2014-11-19                 Lost to follow up           393
# 401      2018-09-26                              Dead           405
# 412      2021-07-05                             Alive           416
# 420      2022-04-15                             Alive           425
#
#     Sex_clinician Doctor Predictions _merge
# 101          male               <NA>   both
# 122        female               <NA>   both
# 181          male               <NA>   both
# 195        female               <NA>   both
# 215          male               <NA>   both
# 227          male               <NA>   both
# 231        female               <NA>   both
# 238        female               <NA>   both
# 289          male               <NA>   both
# 292        female               <NA>   both
# 390          male               <NA>   both
# 401        female               <NA>   both
# 412          male               <NA>   both
# 420          male               <NA>   both

# %%
# Check for duplicate rows within matches1
duplicates_within_matches1 = matches1[matches1.duplicated()]

if not duplicates_within_matches1.empty:
    print("Duplicate rows found within matches1:")
    display(duplicates_within_matches1)
else:
    print("No duplicate rows found within matches1.")
# Out:
# No duplicate rows found within matches1.

# %%
# Remove rows from df_cl_strip where clinical_idx is in the not_in_remission_indices list
df_cl_strip = df_cl_strip[~df_cl_strip['clinical_idx'].isin(not_in_remission_indices)]

print(f"Removed {len(not_in_remission_indices)} rows from df_cl_strip based on 'not in remission' status in matches1.")
print(f"New shape of df_cl_strip: {df_cl_strip.shape}")
# Out:
# Removed 14 rows from df_cl_strip based on 'not in remission' status in matches1.
# New shape of df_cl_strip: (447, 16)

# %%
df_cl_strip.columns
# Out:
# Index(['clinical_idx', 'Previous Treatment', 'NCI Risk', 'Sex', 'Age',
#        'Lineage', 'Bulky Disease', 'Highest presenting WBC',
#        'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ',
#        'Detail cytogenetics', 'Provisional risk', 'MRD Status_EOI',
#        'Final Risk ', 'Doctor Predictions'],
#       dtype='object')

# %%
# Define key columns
# key_cols = ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
#             'Bulky Disease', 'Highest presenting WBC','Final Risk ']
key_cols = [
    'Previous Treatment',
    'NCI Risk',
    # 'Sex',
    'Age',
    'Lineage',
    'Bulky Disease',
    'Highest presenting WBC',
    'Prednisolone Response',
    'CNS Disease',
    'Cytogenetic groups ',
    'Detail cytogenetics',
    'Provisional risk',
    'MRD Status_EOI',
    'Final Risk '
    ]
# key_cols = ['Sex', 'Age','Highest presenting WBC']

# df_cl_strip = df_cl_strip.reset_index().rename(columns={'index': 'clinical_idx'})


# df_full_strip['Age'] = df_full_strip['Age'].astype(float).fillna(0).astype(int)
# df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)
# df_cl_strip['Age'] = df_cl_strip['Age'].astype(float).fillna(0).astype(int)
# df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].astype(float).fillna(0).astype(int)

# df_full_strip['Highest presenting WBC'] = df_full_strip['Highest presenting WBC'].round()
# df_cl_strip['Highest presenting WBC'] = df_cl_strip['Highest presenting WBC'].round()

# Step 1: Inner merge on key columns to find matches
matches2 = pd.merge(df_full_strip,df_cl_strip, on=key_cols, how='right',indicator=True,suffixes=('_full', '_clinician'))

# Step 2: Count number of matching rows
print(f"Number of matching rows: {len(matches2)}")

# Optional: preview some matching rows
# matches.head()
# Out:
# Number of matching rows: 447

# %%
# Select the necessary columns from matches1 for merging
relapse_data = matches1[['clinical_idx', 'Relapsed']].copy()

# Merge df_cl_strip with relapse_data on clinical_idx
df_cl_strip = pd.merge(df_cl_strip, relapse_data, on='clinical_idx', how='left')

# Drop the clinical_idx column from df_cl_strip
df_cl_strip = df_cl_strip.drop('clinical_idx', axis=1)

print("Relapsed column added to df_cl_strip and clinical_idx column removed.")
print(f"New shape of df_cl_strip: {df_cl_strip.shape}")
# Out:
# Relapsed column added to df_cl_strip and clinical_idx column removed.
# New shape of df_cl_strip: (447, 16)

# %%
df_cl_strip = df_cl_strip.reset_index().rename(columns={'index': 'clinical_idx'})

# %%
df_cl_strip
# Out:
#      clinical_idx Previous Treatment  NCI Risk     Sex  Age Lineage  \
# 0               0                 no      high  female    4       b
# 1               1                 no  standard    male    2       b
# 2               2                yes  standard    male    7       b
# 3               3                 no  standard    male    4       b
# 4               4                 no      high    male    8       b
# ..            ...                ...       ...     ...  ...     ...
# 442           442                 no  standard    male    6       b
# 443           443                 no      high    male   11       t
# 444           444                 no  standard  female    3       b
# 445           445                 no  standard    male    1       b
# 446           446                 no  standard    male    2       b
#
#     Bulky Disease  Highest presenting WBC Prednisolone Response CNS Disease  \
# 0              no                  135000                  good          no
# 1              no                   20140                  good          no
# 2             yes                    3830                  good          no
# 3             yes                    6840                  good          no
# 4              no                   70700                  good         yes
# ..            ...                     ...                   ...         ...
# 442           yes                   30950                  good          no
# 443           yes                    4500                  poor          no
# 444           yes                   27000                  good          no
# 445            no                   12900                  good          no
# 446            no                    2000                  good          no
#
#     Cytogenetic groups  Detail cytogenetics Provisional risk MRD Status_EOI  \
# 0         non-high risk             b-other     intermediate           <NA>
# 1         non-high risk  high hyperdiploidy         standard       negative
# 2                  <NA>                <NA>             high       negative
# 3         non-high risk             b-other     intermediate       negative
# 4         non-high risk             b-other             high       negative
# ..                  ...                 ...              ...            ...
# 442       non-high risk  high hyperdiploidy     intermediate       negative
# 443        not required        not required                t              .
# 444       non-high risk             b-other     intermediate       negative
# 445       non-high risk             b-other         standard       negative
# 446       non-high risk  high hyperdiploidy         standard       negative
#
#       Final Risk  Doctor Predictions Relapsed
# 0    intermediate               <NA>       no
# 1        standard               <NA>       no
# 2            high               <NA>       no
# 3    intermediate               <NA>       no
# 4            high               <NA>      yes
# ..            ...                ...      ...
# 442  intermediate               <NA>       no
# 443             .               <NA>       no
# 444  intermediate               <NA>       no
# 445      standard               <NA>      yes
# 446      standard               <NA>       no
#
# [447 rows x 17 columns]

# %%
# Define the path to save the file in your Google Drive
folder_path = '/content/drive/MyDrive/NIR dataset/'
save_path = folder_path + 'df_cl_strip.xlsx'

# Create the directory if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Save the DataFrame to an Excel file
df_cl_strip.to_excel(save_path, index=False)

print(f"DataFrame saved successfully to {save_path}")
# Out:
# DataFrame saved successfully to /content/drive/MyDrive/NIR dataset/df_cl_strip.xlsx

# %%
df_full_strip['Remission status _EOI'].value_counts()

# matches1[matches1['Remission status _EOI']=="not in remission"][["Sl No","clinical_idx"]]["Sl No"].to_list()
# Out:
# Remission status _EOI
# in remission        2118
# .                    118
# not in remission      79
# Name: count, dtype: Int64

# %%
df_full_strip.columns
# Out:
# Index(['Sl No', 'UPN_AI_dataset', 'Previous Treatment', 'Date of Birth',
#        'NCI Risk', 'Sex', 'Date of Diagnosis', 'Age', 'Lineage',
#        'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response',
#        'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics',
#        'Provisional risk', 'Date of Remission_EOI', 'Remission status _EOI',
#        'MRD Status_EOI', 'Final Risk ', 'Date of Completion of treatment',
#        'Relapsed', 'Date of Relapse', 'Time-point of Relapse ',
#        'Type of relapse', 'Site of Relapse ', 'Death', 'Date of Death ',
#        'Treatment death phase',
#        'Treatment abandonment/Disease progresssion/Off protocol',
#        'Date of Treatment abandonment/ Disease progresssion/Off protocol',
#        'Date of Last FU', 'Current status at Last Follow up '],
#       dtype='object')

# %%
# Identify the rows in df_full_strip that match the current df_cl_strip based on key_cols
# We'll use a left merge and keep only the rows that match
matched_in_full_strip = pd.merge(df_full_strip, df_cl_strip[key_cols], on=key_cols, how='inner')

# Get the indices of these matched rows in the original df_full_strip
indices_to_remove_from_full = matched_in_full_strip.index.tolist()

# Remove these rows from df_full_strip
df_full_strip_remaining = df_full_strip.drop(indices_to_remove_from_full)

print(f"Removed {len(indices_to_remove_from_full)} rows from df_full_strip.")
print(f"New shape of df_full_strip_remaining: {df_full_strip_remaining.shape}")
# Out:
# Removed 447 rows from df_full_strip.
# New shape of df_full_strip_remaining: (1884, 33)

# %%
# df_full_strip_remaining['Remission status _EOI'].value_counts()
sl_no_removed = matches1[matches1['Remission status _EOI']=="not in remission"][["Sl No","clinical_idx"]]["Sl No"].to_list()
# Check if "any" df_full_strip_remaining contains sl_no_removed then print those sl no
print(sl_no_removed)
print(df_full_strip_remaining[df_full_strip_remaining['Sl No'].isin(sl_no_removed)])
# if not all(df_full_strip_remaining['Sl No'].isin(sl_no_removed)):
#     print("Not all elements in sl_no_removed are present in df_full_strip_remaining.")
# if all(df_full_strip_remaining['Sl No'].isin(sl_no_removed)):
#     print("All elements in sl_no_removed are present in df_full_strip_remaining.")
# Out:
# [1514, 450, 530, 1973, 2284, 298, 1960, 1595, 2142, 291, 1631, 2230, 60, 2294]
#       Sl No UPN_AI_dataset Previous Treatment        Date of Birth  NCI Risk  \
# 449     450      PT-AI_450                 no        Not available  standard
# 529     530      PT-AI_530                 no        Not available      high
# 1513   1514     PT-AI_1514                yes        Not available  standard
# 1594   1595     PT-AI_1595                 no        Not available  standard
# 1630   1631     PT-AI_1631                yes        Not available      high
# 1959   1960     PT-AI_1960                 no        Not available      high
# 1972   1973     PT-AI_1973                 no        Not available      high
# 2141   2142     PT-AI_2142                 no  2005-03-06 00:00:00      high
# 2229   2230     PT-AI_2230                 no  2011-08-10 00:00:00      high
# 2283   2284     PT-AI_2284                 no  2006-06-03 00:00:00  standard
# 2293   2294     PT-AI_2294                 no  2011-11-14 00:00:00  standard
#
#          Sex Date of Diagnosis  Age Lineage Bulky Disease  \
# 449   female        2017-08-03    6       b            no
# 529     male        2017-10-31   13       b            no
# 1513    male        2016-09-21    3       b            no
# 1594  female        2016-12-17    9       b            no
# 1630    male        2014-05-12   17       b            no
# 1959  female        2015-07-29   13       b           yes
# 1972  female        2015-12-16    5       b            no
# 2141    male        2015-02-07    9       t            no
# 2229  female        2016-10-25    5       t           yes
# 2283    male        2015-03-04    8       b           yes
# 2293    male        2017-03-22    5       b            no
#
#       Highest presenting WBC Prednisolone Response CNS Disease  \
# 449                    30100                  good          no
# 529                    18870                  poor          no
# 1513                   18760                  good          no
# 1594                    3730                  good          no
# 1630                    1600                  good          no
# 1959                  850000                  <NA>          no
# 1972                  280000                  <NA>          no
# 2141                  420000                  poor          no
# 2229                  400000                  poor          no
# 2283                    1100                  good          no
# 2293                    7500                  good          no
#
#      Cytogenetic groups  Detail cytogenetics Provisional risk  \
# 449        non-high risk             b-other         standard
# 529        non-high risk  high hyperdiploidy             high
# 1513       non-high risk             b-other             high
# 1594       non-high risk             b-other         standard
# 1630       non-high risk             b-other             high
# 1959       non-high risk                <NA>             high
# 1972       non-high risk                <NA>             high
# 2141        not required        not required                t
# 2229        not required        not required                t
# 2283       non-high risk  high hyperdiploidy     intermediate
# 2293       non-high risk  high hyperdiploidy         standard
#
#      Date of Remission_EOI Remission status _EOI MRD Status_EOI Final Risk   \
# 449    2017-09-08 00:00:00      not in remission       positive        high
# 529    2017-12-13 00:00:00      not in remission       positive        high
# 1513   2016-11-08 00:00:00      not in remission       positive        high
# 1594   2017-01-30 00:00:00      not in remission       positive        high
# 1630   2014-07-25 00:00:00      not in remission       positive        high
# 1959   2015-10-01 00:00:00      not in remission       positive        high
# 1972   2016-01-22 00:00:00      not in remission       positive        high
# 2141   2015-03-10 00:00:00      not in remission   not required           .
# 2229   2016-11-27 00:00:00      not in remission   not required           t
# 2283   2015-04-21 00:00:00      not in remission       positive        high
# 2293   2017-04-26 00:00:00      not in remission       positive        high
#
#      Date of Completion of treatment Relapsed Date of Relapse  \
# 449                                .       no               .
# 529                                .       no               .
# 1513                             NaN       no               .
# 1594                               .       no               .
# 1630                               .       no               .
# 1959                               .       no               .
# 1972             2018-12-20 00:00:00       no               .
# 2141                               .       no               .
# 2229                               .       no               .
# 2283             2017-10-26 00:00:00       no               .
# 2293             2019-11-06 00:00:00       no               .
#
#      Time-point of Relapse  Type of relapse Site of Relapse  Death  \
# 449                       .               .                .   Yes
# 529                       .               .                .   Yes
# 1513                      .               .                .    No
# 1594                      .               .                .    No
# 1630                      .               .                .    No
# 1959                      .               .                .    No
# 1972                      .               .                .    No
# 2141                      .               .                .   Yes
# 2229                      .               .                .   Yes
# 2283                      .               .                .    No
# 2293                      .               .                .    No
#
#            Date of Death  Treatment death phase  \
# 449   2018-08-13 00:00:00                     .
# 529   2019-07-31 00:00:00                     .
# 1513                    .                     .
# 1594                    .                     .
# 1630                    .                     .
# 1959                    .                     .
# 1972                    .                     .
# 2141  2015-07-02 00:00:00                     .
# 2229  2018-09-26 00:00:00                     .
# 2283                    .                     .
# 2293                    .                     .
#
#      Treatment abandonment/Disease progresssion/Off protocol  \
# 449                                  Yes (Off protocol)
# 529                                  Yes (Off protocol)
# 1513                                                 No
# 1594                                 Yes (Off protocol)
# 1630                                 Yes (Off protocol)
# 1959                                 Yes (Off protocol)
# 1972                                                 No
# 2141                                 Yes (Off protocol)
# 2229                                                 No
# 2283                                                 No
# 2293                                                 No
#
#      Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 449                                 2017-09-08 00:00:00
# 529                                 2017-12-13 00:00:00
# 1513                                                  .
# 1594                                2017-01-30 00:00:00
# 1630                                2014-07-25 00:00:00
# 1959                                2015-10-01 00:00:00
# 1972                                                  .
# 2141                                2015-03-10 00:00:00
# 2229                                                  .
# 2283                                                  .
# 2293                                                  .
#
#      Date of Last FU Current status at Last Follow up
# 449       2018-08-13                              Dead
# 529       2019-07-31                              Dead
# 1513      2022-02-18                             Alive
# 1594      2019-02-28                 Lost to follow up
# 1630      2014-11-19                 Lost to follow up
# 1959      2015-10-05                 Lost to follow up
# 1972      2020-06-13                 Lost to follow up
# 2141      2015-07-02                              Dead
# 2229      2018-09-26                              Dead
# 2283      2022-05-21                             Alive
# 2293      2022-04-15                             Alive

# %%
df_full_strip_remaining.columns
# Out:
# Index(['Sl No', 'UPN_AI_dataset', 'Previous Treatment', 'Date of Birth',
#        'NCI Risk', 'Sex', 'Date of Diagnosis', 'Age', 'Lineage',
#        'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response',
#        'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics',
#        'Provisional risk', 'Date of Remission_EOI', 'Remission status _EOI',
#        'MRD Status_EOI', 'Final Risk ', 'Date of Completion of treatment',
#        'Relapsed', 'Date of Relapse', 'Time-point of Relapse ',
#        'Type of relapse', 'Site of Relapse ', 'Death', 'Date of Death ',
#        'Treatment death phase',
#        'Treatment abandonment/Disease progresssion/Off protocol',
#        'Date of Treatment abandonment/ Disease progresssion/Off protocol',
#        'Date of Last FU', 'Current status at Last Follow up '],
#       dtype='object')

# %%
# Count entries with 'not in remission' in 'Remission status _EOI' in df_full_strip_remaining
not_in_remission_remaining_count = df_full_strip_remaining[df_full_strip_remaining['Remission status _EOI'] == 'not in remission'].shape[0]

print(f"Number of entries in df_full_strip_remaining with 'not in remission' in 'Remission status _EOI': {not_in_remission_remaining_count}")
# Out:
# Number of entries in df_full_strip_remaining with 'not in remission' in 'Remission status _EOI': 66

# %%
# Display entries with 'not in remission' in 'Remission status _EOI' in df_full_strip_remaining
nir_df_full = (df_full_strip_remaining[df_full_strip_remaining['Remission status _EOI'] == 'not in remission'])

# %%
nir_df_full
# Out:
#       Sl No UPN_AI_dataset Previous Treatment        Date of Birth  NCI Risk  \
# 449     450      PT-AI_450                 no        Not available  standard
# 493     494      PT-AI_494                 no        Not available  standard
# 503     504      PT-AI_504                 no        Not available      high
# 529     530      PT-AI_530                 no        Not available      high
# 572     573      PT-AI_573                 no        Not available  standard
# ...     ...            ...                ...                  ...       ...
# 2283   2284     PT-AI_2284                 no  2006-06-03 00:00:00  standard
# 2287   2288     PT-AI_2288                 no  1998-05-20 00:00:00      high
# 2293   2294     PT-AI_2294                 no  2011-11-14 00:00:00  standard
# 2298   2299     PT-AI_2299                 no  2011-12-13 00:00:00  standard
# 2321   2322     PT-AI_2322                 no  2004-10-09 00:00:00      high
#
#          Sex Date of Diagnosis  Age Lineage Bulky Disease  \
# 449   female        2017-08-03    6       b            no
# 493     male        2017-09-18    5       b           yes
# 503   female        2017-10-03    9       b           yes
# 529     male        2017-10-31   13       b            no
# 572     male        2017-12-08    8       b           yes
# ...      ...               ...  ...     ...           ...
# 2283    male        2015-03-04    8       b           yes
# 2287    male        2014-10-04   16       t            no
# 2293    male        2017-03-22    5       b            no
# 2298    male        2017-02-22    5       b            no
# 2321  female        2017-07-26   12       b            no
#
#       Highest presenting WBC Prednisolone Response CNS Disease  \
# 449                    30100                  good          no
# 493                     5130                  poor          no
# 503                   137800                  poor          no
# 529                    18870                  poor          no
# 572                    40000                  poor          no
# ...                      ...                   ...         ...
# 2283                    1100                  good          no
# 2287                  135000                  good          no
# 2293                    7500                  good          no
# 2298                   47600                  good          no
# 2321                   16500                  good          no
#
#      Cytogenetic groups  Detail cytogenetics Provisional risk  \
# 449        non-high risk             b-other         standard
# 493        non-high risk  high hyperdiploidy             high
# 503        non-high risk  high hyperdiploidy             high
# 529        non-high risk  high hyperdiploidy             high
# 572        non-high risk           tcf3-pbx1             high
# ...                  ...                 ...              ...
# 2283       non-high risk  high hyperdiploidy     intermediate
# 2287        not required        not required                t
# 2293       non-high risk  high hyperdiploidy         standard
# 2298       non-high risk             b-other         standard
# 2321       non-high risk  high hyperdiploidy     intermediate
#
#      Date of Remission_EOI Remission status _EOI MRD Status_EOI Final Risk   \
# 449    2017-09-08 00:00:00      not in remission       positive        high
# 493    2017-10-27 00:00:00      not in remission       positive        high
# 503    2017-11-14 00:00:00      not in remission       positive        high
# 529    2017-12-13 00:00:00      not in remission       positive        high
# 572    2018-01-11 00:00:00      not in remission       positive        high
# ...                    ...                   ...            ...         ...
# 2283   2015-04-21 00:00:00      not in remission       positive        high
# 2287   2014-11-13 00:00:00      not in remission   not required           t
# 2293   2017-04-26 00:00:00      not in remission       positive        high
# 2298   2017-03-29 00:00:00      not in remission       positive        high
# 2321   2017-09-02 00:00:00      not in remission       positive        high
#
#      Date of Completion of treatment Relapsed Date of Relapse  \
# 449                                .       no               .
# 493                                .       no               .
# 503                                .       no               .
# 529                                .       no               .
# 572                                .       no               .
# ...                              ...      ...             ...
# 2283             2017-10-26 00:00:00       no               .
# 2287             2017-06-22 00:00:00       no               .
# 2293             2019-11-06 00:00:00       no               .
# 2298             2019-11-04 00:00:00       no               .
# 2321                               .       no               .
#
#      Time-point of Relapse  Type of relapse Site of Relapse  Death  \
# 449                       .               .                .   Yes
# 493                       .               .                .    No
# 503                       .               .                .   Yes
# 529                       .               .                .   Yes
# 572                       .               .                .    No
# ...                     ...             ...              ...   ...
# 2283                      .               .                .    No
# 2287                      .               .                .   Yes
# 2293                      .               .                .    No
# 2298                      .               .                .    No
# 2321                      .               .                .   Yes
#
#            Date of Death  Treatment death phase  \
# 449   2018-08-13 00:00:00                     .
# 493                     .                     .
# 503   2018-04-01 00:00:00                     .
# 529   2019-07-31 00:00:00                     .
# 572                     .                     .
# ...                   ...                   ...
# 2283                    .                     .
# 2287  2020-04-01 00:00:00                     .
# 2293                    .                     .
# 2298                    .                     .
# 2321  2017-12-26 00:00:00                     .
#
#      Treatment abandonment/Disease progresssion/Off protocol  \
# 449                                  Yes (Off protocol)
# 493                                  Yes (Off protocol)
# 503                                  Yes (Off protocol)
# 529                                  Yes (Off protocol)
# 572                                  Yes (Off protocol)
# ...                                                 ...
# 2283                                                 No
# 2287                                                 No
# 2293                                                 No
# 2298                                                 No
# 2321                                                 No
#
#      Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 449                                 2017-09-08 00:00:00
# 493                                 2017-10-27 00:00:00
# 503                                 2017-11-14 00:00:00
# 529                                 2017-12-13 00:00:00
# 572                                 2018-01-17 00:00:00
# ...                                                 ...
# 2283                                                  .
# 2287                                                  .
# 2293                                                  .
# 2298                                                  .
# 2321                                                  .
#
#      Date of Last FU Current status at Last Follow up
# 449       2018-08-13                              Dead
# 493       2020-01-02                 Lost to follow up
# 503       2018-04-01                              Dead
# 529       2019-07-31                              Dead
# 572       2018-03-03                 Lost to follow up
# ...              ...                               ...
# 2283      2022-05-21                             Alive
# 2287      2020-04-01                              Dead
# 2293      2022-04-15                             Alive
# 2298      2022-04-26                             Alive
# 2321      2017-12-26                              Dead
#
# [66 rows x 33 columns]

# %%
# Find duplicate rows within nir_df_full
duplicates_in_nir_df_full = nir_df_full[nir_df_full.duplicated()]

if not duplicates_in_nir_df_full.empty:
    print("Duplicate rows found within nir_df_full:")
    display(duplicates_in_nir_df_full)
else:
    print("No duplicate rows found within nir_df_full.")
# Out:
# No duplicate rows found within nir_df_full.

# %%
df_full_strip.iloc[[1309,1106]]
# Out:
#       Sl No UPN_AI_dataset Previous Treatment  Date of Birth  NCI Risk   Sex  \
# 1309   1310     PT-AI_1310                 no  Not available  standard  male
# 1106   1107     PT-AI_1107                 no  Not available  standard  male
#
#      Date of Diagnosis  Age Lineage Bulky Disease  Highest presenting WBC  \
# 1309        2016-02-19    5       b            no                    2000
# 1106        2015-06-05    5       b            no                    2000
#
#      Prednisolone Response CNS Disease Cytogenetic groups   \
# 1309                  good          no       non-high risk
# 1106                  good          no       non-high risk
#
#      Detail cytogenetics Provisional risk Date of Remission_EOI  \
# 1309  high hyperdiploidy         standard   2016-03-21 00:00:00
# 1106  high hyperdiploidy         standard   2015-07-06 00:00:00
#
#      Remission status _EOI MRD Status_EOI Final Risk   \
# 1309          in remission       negative    standard
# 1106          in remission       negative    standard
#
#      Date of Completion of treatment Relapsed Date of Relapse  \
# 1309             2018-06-06 00:00:00       no               .
# 1106             2017-09-17 00:00:00       no               .
#
#      Time-point of Relapse  Type of relapse Site of Relapse  Death  \
# 1309                      .               .                .    No
# 1106                      .               .                .    No
#
#      Date of Death  Treatment death phase  \
# 1309              .                     .
# 1106              .                     .
#
#      Treatment abandonment/Disease progresssion/Off protocol  \
# 1309                                                 No
# 1106                                                 No
#
#      Date of Treatment abandonment/ Disease progresssion/Off protocol  \
# 1309                                                  .
# 1106                                                  .
#
#      Date of Last FU Current status at Last Follow up
# 1309      2019-09-18                 Lost to follow up
# 1106      2021-09-24                             Alive

# %%
# Step 1: Define key columns for matching
key_cols = ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage',
            'Bulky Disease', 'Highest presenting WBC']

# Step 2: Filter full dataset for 'not in remission'
df_not_in_remission = df_full_strip[df_full_strip['Remission status _EOI'] == 'not in remission']

# Step 2.5: Clean 'Age' column in df_cl to match df_full_strip
df_cl['Age'] = df_cl['Age'].astype(str)

# Step 2.6: Clean 'Highest presenting WBC' column in df_cl to match df_full_strip
df_cl['Highest presenting WBC'] = df_cl['Highest presenting WBC'].astype(str)

# Step 3: Merge with clinician dataset on key columns to see matches
df_matches = df_not_in_remission.merge(
    df_cl,
    on=key_cols,
    how='inner',  # only rows that match on all key_cols
    suffixes=('_full', '_clinician')
)

# Step 4: See results
print(f"Total rows in full dataset with 'not in remission': {len(df_not_in_remission)}")
print(f"Rows matching clinician dataset on key columns: {len(df_matches)}")
display(df_matches.head())
# Out:
# Total rows in full dataset with 'not in remission': 79
# Rows matching clinician dataset on key columns: 13
#   Previous Treatment  NCI Risk     Sex   Age Lineage Bulky Disease  \
# 0                 no  standard  female   7.0       b            no
# 1                yes  standard    male   3.0       b            no
# 2                 no  standard  female   6.0       b            no
# 3                 no      high    male  13.0       b            no
# 4                yes  standard    male   3.0       b            no
#
#   Highest presenting WBC Prednisolone Response_full CNS Disease_full  \
# 0                 2970.0                       good               no
# 1                 2970.0                       good               no
# 2                30100.0                       good               no
# 3                18870.0                       poor               no
# 4                18760.0                       good               no
#
#   Cytogenetic groups _full  ... Prednisolone Response_clinician  \
# 0            non-high risk  ...                            good
# 1                high risk  ...                            good
# 2            non-high risk  ...                            good
# 3            non-high risk  ...                            poor
# 4            non-high risk  ...                            good
#
#   CNS Disease_clinician Cytogenetic groups _clinician  \
# 0                    no                 non-high risk
# 1                    no                     high risk
# 2                    no                 non-high risk
# 3                    no                 non-high risk
# 4                    no                 non-high risk
#
#   Detail cytogenetics_clinician Provisional risk_clinician  \
# 0            high hyperdiploidy                   standard
# 1              kmt2a rearranged                       high
# 2                       b-other                   standard
# 3            high hyperdiploidy                       high
# 4                       b-other                       high
#
#   MRD Status_EOI_clinician Final Risk _clinician Doctor Predictions - Gargi  \
# 0                 positive                  high                         No
# 1                 positive                  high                        Yes
# 2                 positive                  high                        Yes
# 3                 positive                  high                        Yes
# 4                 positive                  high                        Yes
#
#   Doctor's Preference - Prasanth Doctor Predictions
# 0                            Yes                 no
# 1                            Yes                yes
# 2                            Yes                yes
# 3                            Yes                 no
# 4                            Yes                 no
#
# [5 rows x 26 columns]

# %%
# Step 2: Remove matched rows from df_cl
df_remaining = df_cl.merge(df_matches[key_cols], on=key_cols, how='left', indicator=True)
df_remaining = df_remaining[df_remaining['_merge'] == 'left_only'].drop(columns=['_merge'])

# Step 3: Save remaining rows to Excel
df_remaining.to_excel('remaining_rows.xlsx', index=False)

print(f"Rows removed: {len(df_matches)}")
print(f"Remaining rows saved: {len(df_remaining)}")
# Out:
# Rows removed: 13
# Remaining rows saved: 454

# %%
file_path = "/content/new x test.xlsx"
new_x_test = pd.read_excel(file_path)

# %%
print(df_full_strip['Remission status _EOI'].value_counts(dropna=False))
print(df_full_strip.shape)
# Out:
# Remission status _EOI
# in remission        2118
# .                    118
# not in remission      79
# <NA>                  16
# Name: count, dtype: Int64
# (2331, 16)

# %%
# True where exactly 'not in remission', False elsewhere (NA -> <NA>), then fill NA -> False
mask = df_full_strip['Remission status _EOI'].eq('not in remission').fillna(False)

# keep rows where mask is False (i.e. not 'not in remission')
df_rem = df_full_strip.loc[~mask].copy()

# %%
print(df_rem['Remission status _EOI'].value_counts(dropna=False))
print(df_rem.shape)
# Out:
# Remission status _EOI
# in remission    2118
# .                118
# <NA>              16
# Name: count, dtype: Int64
# (2252, 16)

# %%
df_rem = df_rem.drop('Remission status _EOI', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3830246722.py in <cell line: 0>()
# ----> 1 df_rem = df_rem.drop('Remission status _EOI', axis=1)
#       2 print(df_rem.shape)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Remission status _EOI'] not found in axis"

# %%
print(df_rem.shape)
# Out:
# (2252, 15)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Load data

# %%
from google.colab import drive
import os

# Mount Google Drive
try:
    drive.mount('/content/drive')
    print("Google Drive mounted successfully.")
except Exception as e:
    print(f"Error mounting Google Drive: {e}")
    print("Attempting to remount or it might be already mounted.")
    # Optional: add a check here if already mounted
    if not os.path.exists('/content/drive/MyDrive'):
        print("Google Drive not mounted. Please check permissions or try mounting manually.")
# Out:
# Mounted at /content/drive
# Google Drive mounted successfully.

# %%
# Define the folder path in Google Drive
folder_path = '/content/drive/MyDrive/NIR dataset/'

# Load df_train and df_test from the specified folder
try:
    df_train = pd.read_excel(os.path.join(folder_path, 'df_train.xlsx'))
    df_test = pd.read_excel(os.path.join(folder_path, 'df_test.xlsx'))

    print("Data loaded successfully!")
    print(f"df_train shape: {df_train.shape}")
    print(f"df_test shape: {df_test.shape}")

except FileNotFoundError as e:
    print(f"Error: File not found - {e}")
except Exception as e:
    print(f"Error loading data: {e}")
# Out:
# Data loaded successfully!
# df_train shape: (1870, 33)
# df_test shape: (461, 33)

# %% [markdown]
# ### Remove leakage columns

# %%
def remove_columns(df, feature_set='normal'):

    # Define base leakage columns to always remove
    base_leakage_cols = [
        "Sl No",
        "UPN_AI_dataset",
        # All Date columns
        "Date of Birth", "Date of Diagnosis", "Date of Remission_EOI",
        "Date of Completion of treatment", "Date of Relapse",
        "Date of Death ", "Date of Treatment abandonment/ Disease progresssion/Off protocol",
        "Date of Last FU",
        # Relapse & outcome details
        "Time-point of Relapse ", "Type of relapse", "Site of Relapse ",
        "Death", "Treatment death phase",
        "Treatment abandonment/Disease progresssion/Off protocol",
        "Current status at Last Follow up "
    ]

    # Additional columns to remove for minimal feature set
    minimal_cols = [
        "Previous Treatment", "NCI Risk", "Lineage", "Bulky Disease",
        "CNS Disease", "Detail cytogenetics", "Provisional risk",
    ]

    # Combine columns based on feature_set parameter
    if feature_set == 'minimal':
        cols_to_remove = base_leakage_cols + minimal_cols
    else:  # 'normal' or any other value
        cols_to_remove = base_leakage_cols

    # Remove only columns that exist in the dataframe
    existing_cols_to_remove = [c for c in cols_to_remove if c in df.columns]
    df_clean = df.drop(columns=existing_cols_to_remove)

    return df_clean

# %%
df_train_clean = remove_columns(df_train, feature_set='normal')
print(df_train_clean.columns.tolist())
# Out:
# ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ', 'Relapsed']

# %%
df_test_clean = remove_columns(df_test, feature_set='normal')
print(df_test_clean.columns.tolist())
# Out:
# ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'MRD Status_EOI', 'Final Risk ', 'Remission status _EOI', 'Relapsed']

# %% [markdown]
# ### Clean Column Strings

# %%
def clean_string_columns(df, columns_to_clean):
  existing_cols_to_clean = [col for col in columns_to_clean if col in df.columns]

  for col in existing_cols_to_clean:
      df[col] = df[col].astype("string").str.strip().str.lower()

  return df

# %%
df_train_clean = clean_string_columns(df_train_clean, ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ', 'Relapsed'])

# %%
df_test_clean = clean_string_columns(df_test_clean, ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ', 'Relapsed'])

# %% [markdown]
# ### Dealing 'Not in remission' Entries

# %%
print(df_train_clean['Remission status _EOI'].value_counts(dropna=False))
print(f"\n")
print(df_test_clean['Remission status _EOI'].value_counts(dropna=False))
# Out:
# Remission status _EOI
# in remission        1703
# .                     90
# not in remission      65
# <NA>                  12
# Name: count, dtype: Int64
#
#
# Remission status _EOI
# in remission        415
# .                    28
# not in remission     14
# <NA>                  4
# Name: count, dtype: Int64

# %%
# True where exactly 'not in remission', False elsewhere (NA -> <NA>), then fill NA -> False
mask = df_train_clean['Remission status _EOI'].eq('not in remission').fillna(False)

# keep rows where mask is False (i.e. not 'not in remission')
df_train_rem = df_train_clean.loc[~mask].copy()



# True where exactly 'not in remission', False elsewhere (NA -> <NA>), then fill NA -> False
mask1 = df_test_clean['Remission status _EOI'].eq('not in remission').fillna(False)

# keep rows where mask is False (i.e. not 'not in remission')
df_test_rem = df_test_clean.loc[~mask1].copy()

# %%
print(df_train_rem['Remission status _EOI'].value_counts(dropna=False))
print(f"\n")
print(df_test_rem['Remission status _EOI'].value_counts(dropna=False))
# Out:
# Remission status _EOI
# in remission    1703
# .                 90
# <NA>              12
# Name: count, dtype: Int64
#
#
# Remission status _EOI
# in remission    415
# .                28
# <NA>              4
# Name: count, dtype: Int64

# %% [markdown]
# ### Removing Remission status col

# %%
# Remove 'Remission status _EOI' col from df_train_rem and df_test_rem
df_train_remain = df_train_rem.drop('Remission status _EOI', axis=1)
df_test_remain = df_test_rem.drop('Remission status _EOI', axis=1)

# %%
print(df_train_remain.columns.tolist())
print(df_test_remain.columns.tolist())
# Out:
# ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'MRD Status_EOI', 'Final Risk ', 'Relapsed']
# ['Previous Treatment', 'NCI Risk', 'Sex', 'Age', 'Lineage', 'Bulky Disease', 'Highest presenting WBC', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'MRD Status_EOI', 'Final Risk ', 'Relapsed']

# %% [markdown]
# ### Split X and Y data

# %%
# Split df_train_remain into features (X_train) and target (y_train)
X_train = df_train_remain.drop('Relapsed', axis=1)
y_train = df_train_remain['Relapsed']

# Split df_test_remain into features (X_test) and target (y_test)
X_test = df_test_remain.drop('Relapsed', axis=1)
y_test = df_test_remain['Relapsed']

print("Data split into features (X) and target (y) for training and testing.")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Data split into features (X) and target (y) for training and testing.
# X_train shape: (1805, 14)
# y_train shape: (1805,)
# X_test shape: (447, 14)
# y_test shape: (447,)

# %% [markdown]
# ### Missing values

# %%
print("Missing values in X_train:")
print(X_train.isnull().sum())
print("\nPercentage of missing values in X_train:")
print(X_train.isnull().sum() / len(X_train) * 100)


print("\nMissing values in X_test:")
print(X_test.isnull().sum())
print("\nPercentage of missing values in X_test:")
print(X_test.isnull().sum() / len(X_test) * 100)
# Out:
# Missing values in X_train:
# Previous Treatment          0
# NCI Risk                    1
# Sex                         0
# Age                         0
# Lineage                     0
# Bulky Disease              51
# Highest presenting WBC      0
# Prednisolone Response      79
# CNS Disease                77
# Cytogenetic groups         49
# Detail cytogenetics       106
# Provisional risk            0
# MRD Status_EOI             56
# Final Risk                  0
# dtype: int64
#
# Percentage of missing values in X_train:
# Previous Treatment        0.000000
# NCI Risk                  0.055402
# Sex                       0.000000
# Age                       0.000000
# Lineage                   0.000000
# Bulky Disease             2.825485
# Highest presenting WBC    0.000000
# Prednisolone Response     4.376731
# CNS Disease               4.265928
# Cytogenetic groups        2.714681
# Detail cytogenetics       5.872576
# Provisional risk          0.000000
# MRD Status_EOI            3.102493
# Final Risk                0.000000
# dtype: float64
#
# Missing values in X_test:
# Previous Treatment         0
# NCI Risk                   0
# Sex                        0
# Age                        0
# Lineage                    0
# Bulky Disease             10
# Highest presenting WBC     0
# Prednisolone Response     24
# CNS Disease               20
# Cytogenetic groups        19
# Detail cytogenetics       35
# Provisional risk           0
# MRD Status_EOI            17
# Final Risk                 0
# dtype: int64
#
# Percentage of missing values in X_test:
# Previous Treatment        0.000000
# NCI Risk                  0.000000
# Sex                       0.000000
# Age                       0.000000
# Lineage                   0.000000
# Bulky Disease             2.237136
# Highest presenting WBC    0.000000
# Prednisolone Response     5.369128
# CNS Disease               4.474273
# Cytogenetic groups        4.250559
# Detail cytogenetics       7.829978
# Provisional risk          0.000000
# MRD Status_EOI            3.803132
# Final Risk                0.000000
# dtype: float64

# %%
total_missing_train = X_train.isnull().sum().sum()
total_missing_test = X_test.isnull().sum().sum()
total_missing = total_missing_train + total_missing_test
total_values = X_train.size + X_test.size
percentage_missing = (total_missing / total_values) * 100

print(f"Total missing values in X_train: {total_missing_train}")
print(f"Total values in X_train: {X_train.size}")
print(f"% of Total missing values in X_train: {(total_missing_test/X_train.size)*100}")

print(f"\nTotal missing values in X_test: {total_missing_test}")
print(f"Total values in X_test: {X_test.size}")
print(f"% of Total missing values in X_test: {(total_missing_test/X_test.size)*100}")

print(f"\nTotal missing values in the dataset (X_train + X_test): {total_missing}")
print(f"Percentage of total missing values in the dataset: {percentage_missing:.2f}%")
# Out:
# Total missing values in X_train: 419
# Total values in X_train: 25270
# % of Total missing values in X_train: 0.4946576968737634
#
# Total missing values in X_test: 125
# Total values in X_test: 6258
# % of Total missing values in X_test: 1.9974432726110578
#
# Total missing values in the dataset (X_train + X_test): 544
# Percentage of total missing values in the dataset: 1.73%

# %% [markdown]
# ### Imputation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from typing import List, Tuple, Dict
import numpy as np

def impute_train_test(
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    categorical_cols: List[str],
    numeric_cols: List[str],
    numeric_strategy: str = "median",
) -> Tuple[pd.DataFrame, pd.DataFrame, Dict[str, SimpleImputer]]:
    """
    Fit imputers on X_train and transform both X_train and X_test.
    - Categorical: most_frequent
    - Numeric: numeric_strategy (default median)
    """

    # Safety: work on copies
    X_train_imp = X_train.copy()
    X_test_imp  = X_test.copy()

    # Convert pd.NA to np.nan everywhere
    X_train_imp = X_train_imp.replace({pd.NA: np.nan, None: np.nan})
    X_test_imp  = X_test_imp.replace({pd.NA: np.nan, None: np.nan})

    # Filter to existing columns
    cat_cols_exist = [c for c in categorical_cols if c in X_train.columns]
    num_cols_exist = [c for c in numeric_cols if c in X_train.columns]

    # Define imputers
    cat_imputer = SimpleImputer(strategy="most_frequent", missing_values=np.nan)
    num_imputer = SimpleImputer(strategy=numeric_strategy, missing_values=np.nan)

    # --- Fit on TRAIN ---
    if cat_cols_exist:
        # Ensure categorical columns are string type to avoid issues
        for c in cat_cols_exist:
            X_train_imp[c] = X_train_imp[c].astype(str).replace('nan', np.nan)
            X_test_imp[c] = X_test_imp[c].astype(str).replace('nan', np.nan) if c in X_test_imp.columns else X_test_imp[c]

        X_train_imp[cat_cols_exist] = cat_imputer.fit_transform(X_train_imp[cat_cols_exist])
        # Convert back to object type after imputation
        for c in cat_cols_exist:
            X_train_imp[c] = X_train_imp[c].astype(object)

    if num_cols_exist:
        # Convert numeric columns to numeric type, coercing errors to NaN
        for c in num_cols_exist:
            X_train_imp[c] = pd.to_numeric(X_train_imp[c], errors="coerce")
            if c in X_test_imp.columns:
                X_test_imp[c] = pd.to_numeric(X_test_imp[c], errors="coerce")

        X_train_imp[num_cols_exist] = num_imputer.fit_transform(X_train_imp[num_cols_exist])
        # No need to convert back to numeric type after imputation as it should already be numeric

    # --- Transform TEST ---
    cat_cols_test = [c for c in cat_cols_exist if c in X_test_imp.columns]
    num_cols_test = [c for c in num_cols_exist if c in X_test_imp.columns]

    if cat_cols_test:
        X_test_imp[cat_cols_test] = cat_imputer.transform(X_test_imp[cat_cols_test])
        for c in cat_cols_test:
            X_test_imp[c] = X_test_imp[c].astype(object)

    if num_cols_test:
        X_test_imp[num_cols_test] = num_imputer.transform(X_test_imp[num_cols_test])
        # No need to convert back to numeric type after imputation

    imputers = {"cat": cat_imputer, "num": num_imputer}
    return X_train_imp, X_test_imp, imputers

# %%
# Define column types
categorical_cols = ['Previous Treatment', 'NCI Risk', 'Sex', 'Lineage', 'Bulky Disease', 'Prednisolone Response', 'CNS Disease', 'Cytogenetic groups ', 'Detail cytogenetics', 'Provisional risk', 'Remission status _EOI', 'MRD Status_EOI', 'Final Risk ']
numeric_cols = ['Age', 'Highest presenting WBC']

# Apply safe imputation
X_train_imputed, X_test_imputed, fitted_imputers = impute_train_test(
    X_train,
    X_test,
    categorical_cols,
    numeric_cols,
    numeric_strategy="median"
)

# %%
print("Missing values in X_train:")
print(X_train_imputed.isnull().sum())

print("\nMissing values in X_test:")
print(X_test_imputed.isnull().sum())
# Out:
# Missing values in X_train:
# Previous Treatment        0
# NCI Risk                  0
# Sex                       0
# Age                       0
# Lineage                   0
# Bulky Disease             0
# Highest presenting WBC    0
# Prednisolone Response     0
# CNS Disease               0
# Cytogenetic groups        0
# Detail cytogenetics       0
# Provisional risk          0
# MRD Status_EOI            0
# Final Risk                0
# dtype: int64
#
# Missing values in X_test:
# Previous Treatment        0
# NCI Risk                  0
# Sex                       0
# Age                       0
# Lineage                   0
# Bulky Disease             0
# Highest presenting WBC    0
# Prednisolone Response     0
# CNS Disease               0
# Cytogenetic groups        0
# Detail cytogenetics       0
# Provisional risk          0
# MRD Status_EOI            0
# Final Risk                0
# dtype: int64

# %% [markdown]
# ### Encoding: Label & One-hot

# %%
def encode_data_simple(
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    y_train: pd.Series = None,
    y_test: pd.Series = None,
    custom_mapping: Dict[str, Dict[str, int]] = None
):
    """
    Simplified version using manual one-hot encoding to avoid sklearn issues.
    """

    # Default mapping
    default_mapping = {
        'Previous Treatment': {'no': 0, 'yes': 1},
        'NCI Risk': {'standard': 0, 'high': 1},
        'Sex': {'male': 0, 'female': 1},
        'Lineage': {'b': 0, 't': 1},
        'Bulky Disease': {'no': 0, 'yes': 1},
        'Prednisolone Response': {'good': 0, 'poor': 1},
        'CNS Disease': {'no': 0, 'yes': 1},
        'Cytogenetic groups ': {'non-high risk': 1, 'not required': 2, 'high risk': 3},
        'Provisional risk': {'standard': 0, 'intermediate': 1, 'high': 2, 't': 3},
        'Remission status _EOI': {'not in remission': 0, 'in remission': 1},
        'MRD Status_EOI': {'negative': 1, 'not required': 2, 'positive': 3},
        'Final Risk ': {'standard': 0, 'intermediate': 1, 'high': 2, 't': 3},
        'Relapsed': {'no': 0, 'yes': 1}
    }

    mapping = custom_mapping if custom_mapping is not None else default_mapping
    X_train_encoded = X_train.copy()
    X_test_encoded = X_test.copy()
    encoding_info = {'label_mapping': {}}

    # Encode target
    y_train_encoded, y_test_encoded = None, None
    if y_train is not None and y_test is not None:
        if 'Relapsed' in mapping:
            # Create mapping function
            relapsed_map = mapping['Relapsed']
            y_train_encoded = y_train.map(lambda x: relapsed_map.get(str(x).lower(), 0)).astype(int)
            y_test_encoded = y_test.map(lambda x: relapsed_map.get(str(x).lower(), 0)).astype(int)
            encoding_info['label_mapping']['Relapsed'] = mapping['Relapsed']

    # Manual one-hot encoding for 'Detail cytogenetics'
    if 'Detail cytogenetics' in X_train_encoded.columns:
        try:
            # Get all unique categories from training data
            unique_categories = X_train_encoded['Detail cytogenetics'].fillna('unknown').astype(str).unique()

            # Create one-hot encoded columns for training data
            for category in unique_categories:
                col_name = f"cytogenetics_{category}"
                X_train_encoded[col_name] = (X_train_encoded['Detail cytogenetics'].fillna('unknown').astype(str) == category).astype(int)

            # Create same columns for test data (some might be all zeros)
            for category in unique_categories:
                col_name = f"cytogenetics_{category}"
                X_test_encoded[col_name] = (X_test_encoded['Detail cytogenetics'].fillna('unknown').astype(str) == category).astype(int)

            # Drop original column
            X_train_encoded = X_train_encoded.drop('Detail cytogenetics', axis=1)
            X_test_encoded = X_test_encoded.drop('Detail cytogenetics', axis=1)

            encoding_info['onehot_features'] = [f"cytogenetics_{cat}" for cat in unique_categories]

        except Exception as e:
            print(f"Manual one-hot encoding failed: {e}")
            # Fallback to label encoding
            X_train_encoded['Detail cytogenetics'] = X_train_encoded['Detail cytogenetics'].astype('category').cat.codes
            X_test_encoded['Detail cytogenetics'] = X_test_encoded['Detail cytogenetics'].astype('category').cat.codes

    # Apply label encoding to other columns
    for column, value_map in mapping.items():
        if column != 'Relapsed' and column in X_train_encoded.columns:
            # Create a mapping function for this specific column
            def map_value(x, mapping_dict=value_map):
                x_str = str(x).lower().strip() if pd.notna(x) else 'unknown'
                return mapping_dict.get(x_str, 0)  # Default to 0 for unknown values

            X_train_encoded[column] = X_train_encoded[column].apply(map_value)
            if column in X_test_encoded.columns:
                X_test_encoded[column] = X_test_encoded[column].apply(map_value)
            encoding_info['label_mapping'][column] = value_map

    # Handle any remaining categorical columns
    categorical_cols = X_train_encoded.select_dtypes(include=['object', 'category']).columns
    for col in categorical_cols:
        if col not in encoding_info['label_mapping']:
            X_train_encoded[col] = X_train_encoded[col].astype('category').cat.codes
            X_test_encoded[col] = X_test_encoded[col].astype('category').cat.codes
            encoding_info['label_mapping'][col] = 'categorical_encoding_auto'

    # Ensure all columns are numeric
    X_train_encoded = X_train_encoded.apply(pd.to_numeric, errors='coerce').fillna(0)
    X_test_encoded = X_test_encoded.apply(pd.to_numeric, errors='coerce').fillna(0)

    print("Encoding completed successfully!")
    print(f"X_train shape after encoding: {X_train_encoded.shape}")
    print(f"X_test shape after encoding: {X_test_encoded.shape}")

    return X_train_encoded, X_test_encoded, y_train_encoded, y_test_encoded, encoding_info

# %%
X_train_encoded, X_test_encoded, y_train_encoded, y_test_encoded, encoding_info = encode_data_simple(
    X_train_imputed,
    X_test_imputed,
    y_train,
    y_test,
    custom_mapping=None
)
# Out:
# Encoding completed successfully!
# X_train shape after encoding: (1805, 26)
# X_test shape after encoding: (447, 26)

# %%
print(y_train_encoded.unique())
print(y_test_encoded.unique())
# Out:
# [0 1]
# [0 1]

# %%
print(X_train_encoded.dtypes)
print("\n")
print(y_train_encoded.dtypes)
print("\n")
print(X_test_encoded.dtypes)
print("\n")
print(y_test_encoded.dtypes)
# Out:
# Previous Treatment                   int64
# NCI Risk                             int64
# Sex                                  int64
# Age                                float64
# Lineage                              int64
# Bulky Disease                        int64
# Highest presenting WBC             float64
# Prednisolone Response                int64
# CNS Disease                          int64
# Cytogenetic groups                   int64
# Provisional risk                     int64
# MRD Status_EOI                       int64
# Final Risk                           int64
# cytogenetics_not required            int64
# cytogenetics_b-other                 int64
# cytogenetics_high hyperdiploidy      int64
# cytogenetics_etv6-runx1              int64
# cytogenetics_<NA>                    int64
# cytogenetics_bcr-abl1                int64
# cytogenetics_iamp21                  int64
# cytogenetics_tcf3-pbx1               int64
# cytogenetics_kmt2a rearranged        int64
# cytogenetics_low hypodiploidy        int64
# cytogenetics_hypodiploidy            int64
# cytogenetics_tetraploidy             int64
# cytogenetics_near triploidy          int64
# dtype: object
#
#
# int64
#
#
# Previous Treatment                   int64
# NCI Risk                             int64
# Sex                                  int64
# Age                                float64
# Lineage                              int64
# Bulky Disease                        int64
# Highest presenting WBC             float64
# Prednisolone Response                int64
# CNS Disease                          int64
# Cytogenetic groups                   int64
# Provisional risk                     int64
# MRD Status_EOI                       int64
# Final Risk                           int64
# cytogenetics_not required            int64
# cytogenetics_b-other                 int64
# cytogenetics_high hyperdiploidy      int64
# cytogenetics_etv6-runx1              int64
# cytogenetics_<NA>                    int64
# cytogenetics_bcr-abl1                int64
# cytogenetics_iamp21                  int64
# cytogenetics_tcf3-pbx1               int64
# cytogenetics_kmt2a rearranged        int64
# cytogenetics_low hypodiploidy        int64
# cytogenetics_hypodiploidy            int64
# cytogenetics_tetraploidy             int64
# cytogenetics_near triploidy          int64
# dtype: object
#
#
# int64

# %% [markdown]
# ### Save Encoded data

# %%
# Define the folder path in Google Drive
folder_path = '/content/drive/MyDrive/NIR dataset/'

# Create the directory if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Define the file paths for the encoded data
save_path_X_train_encoded = os.path.join(folder_path, 'X_train_encoded.csv')
save_path_y_train_encoded = os.path.join(folder_path, 'y_train_encoded.csv')
save_path_X_test_encoded = os.path.join(folder_path, 'X_test_encoded.csv')
save_path_y_test_encoded = os.path.join(folder_path, 'y_test_encoded.csv')

# Save the encoded DataFrames/Series to CSV files
X_train_encoded.to_csv(save_path_X_train_encoded, index=False)
print(f"X_train_encoded saved successfully to {save_path_X_train_encoded}")

y_train_encoded.to_csv(save_path_y_train_encoded, index=False)
print(f"y_train_encoded saved successfully to {save_path_y_train_encoded}")

X_test_encoded.to_csv(save_path_X_test_encoded, index=False)
print(f"X_test_encoded saved successfully to {save_path_X_test_encoded}")

y_test_encoded.to_csv(save_path_y_test_encoded, index=False)
print(f"y_test_encoded saved successfully to {save_path_y_test_encoded}")
# Out:
# X_train_encoded saved successfully to /content/drive/MyDrive/NIR dataset/X_train_encoded.csv
# y_train_encoded saved successfully to /content/drive/MyDrive/NIR dataset/y_train_encoded.csv
# X_test_encoded saved successfully to /content/drive/MyDrive/NIR dataset/X_test_encoded.csv
# y_test_encoded saved successfully to /content/drive/MyDrive/NIR dataset/y_test_encoded.csv

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Optuna tune function

# %%
def tune_with_optuna_cv(X_train, y_train, n_trials=50, n_splits=5, random_state=42):
    """
    Optuna-tune XGBoost with 5-fold Stratified CV on PR-AUC (Average Precision).
    Handles class imbalance via scale_pos_weight computed per fold.
    Returns: best_model, best_params, best_cv_ap
    """

    # Ensure y is 1-D Series/array
    if isinstance(y_train, pd.DataFrame):
        y_train = y_train.iloc[:, 0]
    y = np.asarray(y_train).reshape(-1)
    X = np.asarray(X_train)

    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    def objective(trial):
        params = {
            "n_estimators": trial.suggest_int("n_estimators", 150, 900),
            "max_depth": trial.suggest_int("max_depth", 3, 12),
            "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
            "gamma": trial.suggest_float("gamma", 0.0, 5.0),
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10.0, log=True),
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-3, 10.0, log=True),
            "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),

            # fixed settings
            "random_state": random_state,
            "n_jobs": -1,
            "eval_metric": "aucpr",          # track PR-AUC during training logs
            "objective": "binary:logistic",
            "base_score": 0.5, # Set base_score to 0.5 to avoid error with single-class folds
            # tip: you can add tree_method="hist" for speed on CPU
        }

        aps = []
        for tr_idx, va_idx in cv.split(X, y):
            X_tr, X_va = X[tr_idx], X[va_idx]
            y_tr, y_va = y[tr_idx], y[va_idx]

            # scale_pos_weight per fold
            pos = (y_tr == 1).sum()
            neg = (y_tr == 0).sum()
            spw = (neg / max(pos, 1)) if pos > 0 else 1.0

            model = XGBClassifier(**params, scale_pos_weight=spw)
            model.fit(X_tr, y_tr, verbose=False)

            y_va_prob = model.predict_proba(X_va)[:, 1]
            aps.append(average_precision_score(y_va, y_va_prob))

        return float(np.mean(aps))

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials)

    # Train best model on full training data (scale_pos_weight from full y)
    best_params = study.best_params.copy()
    pos_full = int((y == 1).sum())
    neg_full = int((y == 0).sum())
    spw_full = (neg_full / max(pos_full, 1)) if pos_full > 0 else 1.0

    best_model = XGBClassifier(
        **best_params,
        random_state=random_state,
        n_jobs=-1,
        eval_metric="aucpr",
        objective="binary:logistic",
        scale_pos_weight=spw_full,
        base_score=0.5, # Set base_score to 0.5 for the final model as well
    )
    best_model.fit(X, y, verbose=False)

    return best_model, best_params

# %%
xgb_model, xgb_params = tune_with_optuna_cv(X_train_encoded, y_train_encoded, n_trials=100)
# Out:
# [I 2025-09-29 21:32:12,752] A new study created in memory with name: no-name-f1be3d0b-d04e-4682-992f-f5fc7f62eb9c
# [I 2025-09-29 21:32:18,099] Trial 0 finished with value: 0.37136309660738037 and parameters: {'n_estimators': 582, 'max_depth': 3, 'learning_rate': 0.07423412753938873, 'subsample': 0.6973157983373572, 'colsample_bytree': 0.9954152094575881, 'gamma': 0.654563448777537, 'reg_lambda': 0.0346259325892464, 'reg_alpha': 3.242698509422461, 'min_child_weight': 1}. Best is trial 0 with value: 0.37136309660738037.
# [I 2025-09-29 21:32:20,196] Trial 1 finished with value: 0.385363019801512 and parameters: {'n_estimators': 900, 'max_depth': 8, 'learning_rate': 0.004033243210805995, 'subsample': 0.5847039687193727, 'colsample_bytree': 0.7506559612080177, 'gamma': 4.052267813666568, 'reg_lambda': 0.0056208323337075166, 'reg_alpha': 3.5976703634804257, 'min_child_weight': 1}. Best is trial 1 with value: 0.385363019801512.
# [I 2025-09-29 21:32:20,704] Trial 2 finished with value: 0.3856029218321537 and parameters: {'n_estimators': 471, 'max_depth': 3, 'learning_rate': 0.14012754573284783, 'subsample': 0.8158555507112644, 'colsample_bytree': 0.5717442200277808, 'gamma': 1.8952989903781985, 'reg_lambda': 0.217908850646804, 'reg_alpha': 0.048182121911908904, 'min_child_weight': 9}. Best is trial 2 with value: 0.3856029218321537.
# [I 2025-09-29 21:32:22,085] Trial 3 finished with value: 0.37908666886842657 and parameters: {'n_estimators': 684, 'max_depth': 12, 'learning_rate': 0.021453600948824147, 'subsample': 0.970322060542333, 'colsample_bytree': 0.8690210091761452, 'gamma': 2.783005701152788, 'reg_lambda': 0.08568136227501433, 'reg_alpha': 3.968435895436282, 'min_child_weight': 8}. Best is trial 2 with value: 0.3856029218321537.
# [I 2025-09-29 21:32:23,663] Trial 4 finished with value: 0.3744321870493975 and parameters: {'n_estimators': 576, 'max_depth': 11, 'learning_rate': 0.016226865127680616, 'subsample': 0.6660295860892869, 'colsample_bytree': 0.8722881406727191, 'gamma': 1.6966279345054396, 'reg_lambda': 0.0017892236384211629, 'reg_alpha': 0.18468881320817518, 'min_child_weight': 5}. Best is trial 2 with value: 0.3856029218321537.
# [I 2025-09-29 21:32:24,607] Trial 5 finished with value: 0.3905443738095661 and parameters: {'n_estimators': 806, 'max_depth': 9, 'learning_rate': 0.038430849921303384, 'subsample': 0.611241221958843, 'colsample_bytree': 0.9234787870089314, 'gamma': 1.8771844918373608, 'reg_lambda': 5.234939423856594, 'reg_alpha': 8.97464951185813, 'min_child_weight': 1}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:25,528] Trial 6 finished with value: 0.38736175888261043 and parameters: {'n_estimators': 542, 'max_depth': 10, 'learning_rate': 0.014861093429221055, 'subsample': 0.8054325266189628, 'colsample_bytree': 0.579507807832973, 'gamma': 2.358476088086981, 'reg_lambda': 8.130326521909575, 'reg_alpha': 0.027552513968419075, 'min_child_weight': 8}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:30,471] Trial 7 finished with value: 0.3826674414149872 and parameters: {'n_estimators': 611, 'max_depth': 3, 'learning_rate': 0.10009716541752295, 'subsample': 0.80776225172649, 'colsample_bytree': 0.7072155991078852, 'gamma': 2.447534500591285, 'reg_lambda': 0.9855019631530212, 'reg_alpha': 0.0013237069803093504, 'min_child_weight': 4}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:32,512] Trial 8 finished with value: 0.36862838495234945 and parameters: {'n_estimators': 189, 'max_depth': 12, 'learning_rate': 0.09444062240800813, 'subsample': 0.8814941847072582, 'colsample_bytree': 0.6398912366754919, 'gamma': 0.17400947241887676, 'reg_lambda': 5.992402804430471, 'reg_alpha': 0.0970455631253208, 'min_child_weight': 10}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:33,049] Trial 9 finished with value: 0.375645340795741 and parameters: {'n_estimators': 250, 'max_depth': 5, 'learning_rate': 0.058842669740582616, 'subsample': 0.7041840332342064, 'colsample_bytree': 0.9599992418849492, 'gamma': 3.086842326797778, 'reg_lambda': 0.5179468295865592, 'reg_alpha': 0.002169704251658098, 'min_child_weight': 6}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:47,033] Trial 10 finished with value: 0.3837389851475999 and parameters: {'n_estimators': 895, 'max_depth': 8, 'learning_rate': 0.0011931757187101475, 'subsample': 0.525316580213607, 'colsample_bytree': 0.8431715361600496, 'gamma': 4.802700543084716, 'reg_lambda': 1.439037889381192, 'reg_alpha': 0.7813760667806906, 'min_child_weight': 3}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:49,599] Trial 11 finished with value: 0.3899571882388445 and parameters: {'n_estimators': 397, 'max_depth': 10, 'learning_rate': 0.01797217324196087, 'subsample': 0.6165173945798499, 'colsample_bytree': 0.5180052027570866, 'gamma': 1.194617416649793, 'reg_lambda': 7.422896753191768, 'reg_alpha': 0.01272452443148132, 'min_child_weight': 7}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:52,720] Trial 12 finished with value: 0.38229226573063724 and parameters: {'n_estimators': 363, 'max_depth': 9, 'learning_rate': 0.00668087854821289, 'subsample': 0.6072719216707974, 'colsample_bytree': 0.7637091086358867, 'gamma': 1.1699920811682514, 'reg_lambda': 2.869298684009843, 'reg_alpha': 0.008884406417844796, 'min_child_weight': 6}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:53,908] Trial 13 finished with value: 0.35333582353409976 and parameters: {'n_estimators': 753, 'max_depth': 7, 'learning_rate': 0.28849626940575807, 'subsample': 0.5049280452976778, 'colsample_bytree': 0.5097353340177425, 'gamma': 1.163933506568144, 'reg_lambda': 7.8993606699697985, 'reg_alpha': 0.009042674396178497, 'min_child_weight': 3}. Best is trial 5 with value: 0.3905443738095661.
# [I 2025-09-29 21:32:55,674] Trial 14 finished with value: 0.39073907434771404 and parameters: {'n_estimators': 405, 'max_depth': 6, 'learning_rate': 0.029737287638121654, 'subsample': 0.612874643522525, 'colsample_bytree': 0.9235387163138756, 'gamma': 3.3364061206260804, 'reg_lambda': 0.4514452397814294, 'reg_alpha': 0.4859923534387917, 'min_child_weight': 7}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:32:58,150] Trial 15 finished with value: 0.38269153415037216 and parameters: {'n_estimators': 774, 'max_depth': 6, 'learning_rate': 0.037392659535152216, 'subsample': 0.5634290659955031, 'colsample_bytree': 0.932141290976039, 'gamma': 3.505756499696439, 'reg_lambda': 0.3144186525954785, 'reg_alpha': 9.948588374908958, 'min_child_weight': 3}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:32:58,968] Trial 16 finished with value: 0.38649787408808967 and parameters: {'n_estimators': 380, 'max_depth': 6, 'learning_rate': 0.007125432760724577, 'subsample': 0.6554857656926785, 'colsample_bytree': 0.81729913653374, 'gamma': 3.788669495723485, 'reg_lambda': 0.02651862388906885, 'reg_alpha': 0.9526529772340832, 'min_child_weight': 5}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:32:59,449] Trial 17 finished with value: 0.3864419018761901 and parameters: {'n_estimators': 288, 'max_depth': 6, 'learning_rate': 0.03127979205008897, 'subsample': 0.7621802668709056, 'colsample_bytree': 0.9109957205686722, 'gamma': 4.352475603621412, 'reg_lambda': 2.1724205431283408, 'reg_alpha': 0.452841401454361, 'min_child_weight': 7}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:32:59,939] Trial 18 finished with value: 0.38486691000887785 and parameters: {'n_estimators': 469, 'max_depth': 5, 'learning_rate': 0.21850177215072447, 'subsample': 0.7237120379898763, 'colsample_bytree': 0.9944800230058273, 'gamma': 3.195205366747138, 'reg_lambda': 0.08705286267966793, 'reg_alpha': 9.79110270233422, 'min_child_weight': 2}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:01,396] Trial 19 finished with value: 0.36476532082894153 and parameters: {'n_estimators': 780, 'max_depth': 9, 'learning_rate': 0.038609123666990014, 'subsample': 0.553885153636673, 'colsample_bytree': 0.8027364500471489, 'gamma': 1.8745477456189599, 'reg_lambda': 0.528443704580504, 'reg_alpha': 0.21362694024407072, 'min_child_weight': 10}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:02,808] Trial 20 finished with value: 0.38107743171072156 and parameters: {'n_estimators': 663, 'max_depth': 7, 'learning_rate': 0.001968547782715053, 'subsample': 0.6467453987371226, 'colsample_bytree': 0.915576314831397, 'gamma': 4.993892651947443, 'reg_lambda': 0.017532340577763175, 'reg_alpha': 1.9281487727366349, 'min_child_weight': 4}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:03,902] Trial 21 finished with value: 0.3866315667480036 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.008633614942280226, 'subsample': 0.6199973401319846, 'colsample_bytree': 0.6902056131856719, 'gamma': 1.3137991452402056, 'reg_lambda': 3.6352928834795986, 'reg_alpha': 0.02113466894902296, 'min_child_weight': 7}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:05,145] Trial 22 finished with value: 0.3749455606174924 and parameters: {'n_estimators': 459, 'max_depth': 10, 'learning_rate': 0.022950012621951264, 'subsample': 0.6193584113195846, 'colsample_bytree': 0.5039912004701576, 'gamma': 0.5162519704013515, 'reg_lambda': 1.1001991533532054, 'reg_alpha': 0.004806665025287485, 'min_child_weight': 7}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:05,852] Trial 23 finished with value: 0.38494874322335726 and parameters: {'n_estimators': 317, 'max_depth': 10, 'learning_rate': 0.011303212823545562, 'subsample': 0.5668568930672991, 'colsample_bytree': 0.6521994202264547, 'gamma': 2.158187656667455, 'reg_lambda': 3.7535809972366354, 'reg_alpha': 0.07303468746733695, 'min_child_weight': 8}. Best is trial 14 with value: 0.39073907434771404.
# [I 2025-09-29 21:33:06,237] Trial 24 finished with value: 0.3917546603473629 and parameters: {'n_estimators': 178, 'max_depth': 11, 'learning_rate': 0.04762696722606641, 'subsample': 0.6600007766559144, 'colsample_bytree': 0.8815803085655187, 'gamma': 2.754888656855812, 'reg_lambda': 9.951378091884942, 'reg_alpha': 0.23388502666122182, 'min_child_weight': 6}. Best is trial 24 with value: 0.3917546603473629.
# [I 2025-09-29 21:33:06,649] Trial 25 finished with value: 0.3841040022308051 and parameters: {'n_estimators': 204, 'max_depth': 11, 'learning_rate': 0.0482828714071119, 'subsample': 0.6781219931187948, 'colsample_bytree': 0.950661495474612, 'gamma': 3.180762484479985, 'reg_lambda': 0.1506228547937836, 'reg_alpha': 0.27244903841682, 'min_child_weight': 6}. Best is trial 24 with value: 0.3917546603473629.
# [I 2025-09-29 21:33:07,036] Trial 26 finished with value: 0.3855021343674348 and parameters: {'n_estimators': 236, 'max_depth': 11, 'learning_rate': 0.1341986427090327, 'subsample': 0.7415339399450135, 'colsample_bytree': 0.8759863473354842, 'gamma': 2.7479362143261508, 'reg_lambda': 0.5813208500938147, 'reg_alpha': 1.0837784974566032, 'min_child_weight': 5}. Best is trial 24 with value: 0.3917546603473629.
# [I 2025-09-29 21:33:07,346] Trial 27 finished with value: 0.3949977128404346 and parameters: {'n_estimators': 155, 'max_depth': 5, 'learning_rate': 0.060013443549248736, 'subsample': 0.5367389925578303, 'colsample_bytree': 0.7927892680966809, 'gamma': 3.5258481446271537, 'reg_lambda': 1.814642122518128, 'reg_alpha': 0.38358844724098345, 'min_child_weight': 4}. Best is trial 27 with value: 0.3949977128404346.
# [I 2025-09-29 21:33:07,656] Trial 28 finished with value: 0.39819187623991825 and parameters: {'n_estimators': 162, 'max_depth': 4, 'learning_rate': 0.026483430954038305, 'subsample': 0.5057637609448635, 'colsample_bytree': 0.7946685625876639, 'gamma': 3.5963733759454444, 'reg_lambda': 1.927477967693441, 'reg_alpha': 0.39767741257205214, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:08,098] Trial 29 finished with value: 0.3860737961331014 and parameters: {'n_estimators': 158, 'max_depth': 4, 'learning_rate': 0.06593405716346128, 'subsample': 0.5244591600758379, 'colsample_bytree': 0.7915894684404191, 'gamma': 3.768277999681732, 'reg_lambda': 2.0185654071318773, 'reg_alpha': 0.16538350153018133, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:09,445] Trial 30 finished with value: 0.38498713282171954 and parameters: {'n_estimators': 294, 'max_depth': 4, 'learning_rate': 0.08174039900888255, 'subsample': 0.5021948274041752, 'colsample_bytree': 0.7137070458563947, 'gamma': 4.34697111631243, 'reg_lambda': 1.1281040422099495, 'reg_alpha': 1.7163336515131289, 'min_child_weight': 2}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:11,001] Trial 31 finished with value: 0.38784463096938604 and parameters: {'n_estimators': 159, 'max_depth': 5, 'learning_rate': 0.02673284696527454, 'subsample': 0.5450322881200451, 'colsample_bytree': 0.8305605792411858, 'gamma': 3.4197543591131185, 'reg_lambda': 0.639862594532059, 'reg_alpha': 0.43106701377423595, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:11,862] Trial 32 finished with value: 0.39459169566222413 and parameters: {'n_estimators': 240, 'max_depth': 4, 'learning_rate': 0.05293206175248398, 'subsample': 0.5845137765864309, 'colsample_bytree': 0.7810497064820658, 'gamma': 2.835413666505487, 'reg_lambda': 0.3174098615327398, 'reg_alpha': 0.47249692939560106, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:12,306] Trial 33 finished with value: 0.39013985422398695 and parameters: {'n_estimators': 232, 'max_depth': 4, 'learning_rate': 0.05256179884385472, 'subsample': 0.5417223972898209, 'colsample_bytree': 0.7646411715122315, 'gamma': 2.7053878801016373, 'reg_lambda': 0.1853279813002864, 'reg_alpha': 0.04830225823880628, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:12,593] Trial 34 finished with value: 0.38969317788267616 and parameters: {'n_estimators': 196, 'max_depth': 3, 'learning_rate': 0.16583933241136745, 'subsample': 0.5884918606898093, 'colsample_bytree': 0.7325967085818615, 'gamma': 3.8570019146365437, 'reg_lambda': 0.043166323000960606, 'reg_alpha': 0.3150200809795327, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:13,083] Trial 35 finished with value: 0.3761713759738397 and parameters: {'n_estimators': 325, 'max_depth': 4, 'learning_rate': 0.11291840896945081, 'subsample': 0.5819270690554053, 'colsample_bytree': 0.7825447732387821, 'gamma': 2.9652467731007244, 'reg_lambda': 1.9211179197394914, 'reg_alpha': 0.12189188635167619, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:13,371] Trial 36 finished with value: 0.39257397054802945 and parameters: {'n_estimators': 151, 'max_depth': 3, 'learning_rate': 0.07111009942533474, 'subsample': 0.5290035556313352, 'colsample_bytree': 0.8630803177201001, 'gamma': 4.164804908675139, 'reg_lambda': 4.056549650366654, 'reg_alpha': 0.596250906544246, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:13,693] Trial 37 finished with value: 0.3894576151721162 and parameters: {'n_estimators': 236, 'max_depth': 3, 'learning_rate': 0.07354378748040383, 'subsample': 0.5011707215229718, 'colsample_bytree': 0.8549151403738432, 'gamma': 4.201267167991263, 'reg_lambda': 0.002092080569569569, 'reg_alpha': 4.232563482441309, 'min_child_weight': 3}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:14,000] Trial 38 finished with value: 0.38083532681954957 and parameters: {'n_estimators': 277, 'max_depth': 3, 'learning_rate': 0.15694158384767123, 'subsample': 0.9563965345785372, 'colsample_bytree': 0.8186215461989942, 'gamma': 3.6506671426036346, 'reg_lambda': 0.3104802213020294, 'reg_alpha': 1.7743799258532096, 'min_child_weight': 2}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:14,354] Trial 39 finished with value: 0.3841922034377951 and parameters: {'n_estimators': 155, 'max_depth': 5, 'learning_rate': 0.012876523643785512, 'subsample': 0.5291136092565656, 'colsample_bytree': 0.7781222666534108, 'gamma': 4.555014527373653, 'reg_lambda': 4.211205863023179, 'reg_alpha': 0.6908490712442228, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:14,770] Trial 40 finished with value: 0.38705990842844995 and parameters: {'n_estimators': 208, 'max_depth': 4, 'learning_rate': 0.01948171467141888, 'subsample': 0.5877626308661528, 'colsample_bytree': 0.6751322083063654, 'gamma': 2.292548980209832, 'reg_lambda': 0.8395818452045145, 'reg_alpha': 3.551420745551669, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:15,052] Trial 41 finished with value: 0.3907831012212486 and parameters: {'n_estimators': 160, 'max_depth': 3, 'learning_rate': 0.04505953807602444, 'subsample': 0.6403342503516034, 'colsample_bytree': 0.8837127050147632, 'gamma': 4.026806456608321, 'reg_lambda': 2.731289370479882, 'reg_alpha': 0.132184748696257, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:15,522] Trial 42 finished with value: 0.3879238649259127 and parameters: {'n_estimators': 261, 'max_depth': 4, 'learning_rate': 0.061359958102603224, 'subsample': 0.5711360097831191, 'colsample_bytree': 0.750977266485041, 'gamma': 2.614313334728093, 'reg_lambda': 8.811335421892396, 'reg_alpha': 0.24247438418281755, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:15,911] Trial 43 finished with value: 0.39353051602383776 and parameters: {'n_estimators': 199, 'max_depth': 5, 'learning_rate': 0.07487107465424525, 'subsample': 0.5318469690585705, 'colsample_bytree': 0.8459737235576027, 'gamma': 2.892294241580315, 'reg_lambda': 5.412391467424828, 'reg_alpha': 0.08241812011879268, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:16,309] Trial 44 finished with value: 0.3900840039441805 and parameters: {'n_estimators': 210, 'max_depth': 5, 'learning_rate': 0.08637514734144383, 'subsample': 0.530698815779225, 'colsample_bytree': 0.8490077743035546, 'gamma': 3.012062987329556, 'reg_lambda': 5.0433074025287885, 'reg_alpha': 0.06527046690359428, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:16,824] Trial 45 finished with value: 0.38383162794197967 and parameters: {'n_estimators': 338, 'max_depth': 5, 'learning_rate': 0.11514696027405467, 'subsample': 0.519869714480746, 'colsample_bytree': 0.8098169124026098, 'gamma': 4.069203593176681, 'reg_lambda': 1.5269237045349244, 'reg_alpha': 0.032852681364102146, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:17,181] Trial 46 finished with value: 0.3861759431655071 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.19445404585108206, 'subsample': 0.549230446165408, 'colsample_bytree': 0.7267442436281166, 'gamma': 3.6090463107210464, 'reg_lambda': 3.095294646362737, 'reg_alpha': 0.6001888997715518, 'min_child_weight': 3}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:17,500] Trial 47 finished with value: 0.38701571768948845 and parameters: {'n_estimators': 189, 'max_depth': 4, 'learning_rate': 0.03524509930510589, 'subsample': 0.8675214002231907, 'colsample_bytree': 0.8333871115161883, 'gamma': 3.3450200802606385, 'reg_lambda': 5.924693931277936, 'reg_alpha': 1.222049145937111, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:18,483] Trial 48 finished with value: 0.38462118103463433 and parameters: {'n_estimators': 521, 'max_depth': 7, 'learning_rate': 0.02499362722820176, 'subsample': 0.5900153704737889, 'colsample_bytree': 0.8941354518812372, 'gamma': 2.9617658298884053, 'reg_lambda': 0.051922463415565966, 'reg_alpha': 0.3788573674062808, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:18,866] Trial 49 finished with value: 0.3881222940691846 and parameters: {'n_estimators': 212, 'max_depth': 6, 'learning_rate': 0.0665967447703515, 'subsample': 0.5114637987014342, 'colsample_bytree': 0.8594171772288619, 'gamma': 4.616288110638266, 'reg_lambda': 0.869205164479805, 'reg_alpha': 0.10579470809293041, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:19,313] Trial 50 finished with value: 0.3858568164033549 and parameters: {'n_estimators': 297, 'max_depth': 3, 'learning_rate': 0.08740937633335345, 'subsample': 0.557527674677786, 'colsample_bytree': 0.7445854492080692, 'gamma': 2.445197736340263, 'reg_lambda': 0.31608512720726956, 'reg_alpha': 0.6370056744769695, 'min_child_weight': 8}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:19,718] Trial 51 finished with value: 0.38910904343638963 and parameters: {'n_estimators': 185, 'max_depth': 12, 'learning_rate': 0.04435638646812569, 'subsample': 0.694249598780388, 'colsample_bytree': 0.8002280056455536, 'gamma': 2.8425416665735286, 'reg_lambda': 9.979831810362688, 'reg_alpha': 0.18472890393123287, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:20,120] Trial 52 finished with value: 0.3877751016927142 and parameters: {'n_estimators': 153, 'max_depth': 8, 'learning_rate': 0.053818346083249376, 'subsample': 0.5459245991011478, 'colsample_bytree': 0.8865777254280153, 'gamma': 2.156722343386285, 'reg_lambda': 5.829501630908564, 'reg_alpha': 0.32710292107166944, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:20,520] Trial 53 finished with value: 0.3892049864358075 and parameters: {'n_estimators': 185, 'max_depth': 5, 'learning_rate': 0.03052090692433078, 'subsample': 0.599766290612821, 'colsample_bytree': 0.8991667513189676, 'gamma': 3.3778293476983867, 'reg_lambda': 1.615022063294123, 'reg_alpha': 0.08360655239185838, 'min_child_weight': 6}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:20,928] Trial 54 finished with value: 0.3931726265304666 and parameters: {'n_estimators': 228, 'max_depth': 4, 'learning_rate': 0.04037677535417784, 'subsample': 0.6379131239102488, 'colsample_bytree': 0.867166814901823, 'gamma': 3.9480600744550176, 'reg_lambda': 3.094147976526275, 'reg_alpha': 0.16874055481972774, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:21,376] Trial 55 finished with value: 0.3944263310215392 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.015933316447038947, 'subsample': 0.6342641112389146, 'colsample_bytree': 0.825551921891071, 'gamma': 3.9407941546659364, 'reg_lambda': 2.2648233870725387, 'reg_alpha': 0.04645578426414028, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:22,600] Trial 56 finished with value: 0.390312197750807 and parameters: {'n_estimators': 357, 'max_depth': 4, 'learning_rate': 0.016151077137536624, 'subsample': 0.6331744569949791, 'colsample_bytree': 0.7696470714242253, 'gamma': 3.914233534415902, 'reg_lambda': 2.755337204269506, 'reg_alpha': 0.044671429569571555, 'min_child_weight': 8}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:24,784] Trial 57 finished with value: 0.38658271477717837 and parameters: {'n_estimators': 261, 'max_depth': 5, 'learning_rate': 0.021912438292108885, 'subsample': 0.7697643670269182, 'colsample_bytree': 0.8275351834365822, 'gamma': 3.6495009221294596, 'reg_lambda': 1.1577818875354178, 'reg_alpha': 0.0163452576169684, 'min_child_weight': 9}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:26,059] Trial 58 finished with value: 0.38880589824341666 and parameters: {'n_estimators': 427, 'max_depth': 6, 'learning_rate': 0.009646916948615388, 'subsample': 0.6843098925078139, 'colsample_bytree': 0.7936315722525995, 'gamma': 3.5547499686731316, 'reg_lambda': 2.3109879529434285, 'reg_alpha': 0.02798959352680738, 'min_child_weight': 9}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:26,549] Trial 59 finished with value: 0.380753042810049 and parameters: {'n_estimators': 238, 'max_depth': 4, 'learning_rate': 0.0041569196489810905, 'subsample': 0.576205398657605, 'colsample_bytree': 0.8408616611142593, 'gamma': 3.1930088574805846, 'reg_lambda': 0.009851875659091456, 'reg_alpha': 0.15439088883666946, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:27,021] Trial 60 finished with value: 0.38748664560330515 and parameters: {'n_estimators': 313, 'max_depth': 5, 'learning_rate': 0.037198784460654104, 'subsample': 0.7067780350868298, 'colsample_bytree': 0.9407270469252722, 'gamma': 4.403368062813277, 'reg_lambda': 0.7939459250886494, 'reg_alpha': 0.03981165749557902, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:27,422] Trial 61 finished with value: 0.3839849667356559 and parameters: {'n_estimators': 222, 'max_depth': 3, 'learning_rate': 0.01455779087971605, 'subsample': 0.532914375112616, 'colsample_bytree': 0.8695143776602136, 'gamma': 4.128855270405995, 'reg_lambda': 4.29968794060602, 'reg_alpha': 0.05745515580368779, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:27,803] Trial 62 finished with value: 0.3892507964717091 and parameters: {'n_estimators': 271, 'max_depth': 4, 'learning_rate': 0.1155331135426897, 'subsample': 0.5625705879518864, 'colsample_bytree': 0.8557831541823417, 'gamma': 3.9193032375435504, 'reg_lambda': 6.811974205553284, 'reg_alpha': 0.5077346142770828, 'min_child_weight': 7}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:28,073] Trial 63 finished with value: 0.39715411062371897 and parameters: {'n_estimators': 178, 'max_depth': 4, 'learning_rate': 0.07284831390601763, 'subsample': 0.6288825681244412, 'colsample_bytree': 0.5966138182310523, 'gamma': 4.263684077836478, 'reg_lambda': 1.2970878075106997, 'reg_alpha': 0.7774885601959499, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:29,039] Trial 64 finished with value: 0.3955996628794473 and parameters: {'n_estimators': 859, 'max_depth': 5, 'learning_rate': 0.03102318380192184, 'subsample': 0.6351665720998719, 'colsample_bytree': 0.8129288425801631, 'gamma': 4.894669309569118, 'reg_lambda': 0.12024214891510579, 'reg_alpha': 0.9244149742395723, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:29,810] Trial 65 finished with value: 0.38995347095646393 and parameters: {'n_estimators': 631, 'max_depth': 6, 'learning_rate': 0.03072693344559729, 'subsample': 0.6076202514015024, 'colsample_bytree': 0.5773298083644643, 'gamma': 4.903944488194318, 'reg_lambda': 0.16148476632593917, 'reg_alpha': 1.3242049613455813, 'min_child_weight': 3}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:30,784] Trial 66 finished with value: 0.3941518655732949 and parameters: {'n_estimators': 841, 'max_depth': 5, 'learning_rate': 0.019206904240782967, 'subsample': 0.6284704498938684, 'colsample_bytree': 0.553963573004964, 'gamma': 4.419224011873604, 'reg_lambda': 0.06941017934865334, 'reg_alpha': 0.8480910093306054, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:31,736] Trial 67 finished with value: 0.39068472203199184 and parameters: {'n_estimators': 866, 'max_depth': 6, 'learning_rate': 0.01889138500741878, 'subsample': 0.6606670658005722, 'colsample_bytree': 0.5436944663975709, 'gamma': 4.690604866584227, 'reg_lambda': 0.06333903231009455, 'reg_alpha': 0.8528032357606325, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:32,779] Trial 68 finished with value: 0.3897009707939557 and parameters: {'n_estimators': 897, 'max_depth': 5, 'learning_rate': 0.012214820337934603, 'subsample': 0.6230165752391754, 'colsample_bytree': 0.6152022114457028, 'gamma': 4.4691391853843685, 'reg_lambda': 0.03155697595281997, 'reg_alpha': 2.4930771516888885, 'min_child_weight': 3}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:33,617] Trial 69 finished with value: 0.38434058026339973 and parameters: {'n_estimators': 852, 'max_depth': 4, 'learning_rate': 0.025910018232774352, 'subsample': 0.6674603770172267, 'colsample_bytree': 0.6007344975892716, 'gamma': 4.726252089437672, 'reg_lambda': 0.12714503186170328, 'reg_alpha': 5.354269427708481, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:34,604] Trial 70 finished with value: 0.39010146934290163 and parameters: {'n_estimators': 820, 'max_depth': 4, 'learning_rate': 0.016921112144647265, 'subsample': 0.5977816858964806, 'colsample_bytree': 0.545251414814767, 'gamma': 4.2765951649436085, 'reg_lambda': 0.2410307423450196, 'reg_alpha': 2.529087906057038, 'min_child_weight': 2}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:35,304] Trial 71 finished with value: 0.389222251860205 and parameters: {'n_estimators': 694, 'max_depth': 5, 'learning_rate': 0.05533579456585409, 'subsample': 0.6242776714933447, 'colsample_bytree': 0.5535344570060229, 'gamma': 4.55447658353531, 'reg_lambda': 0.09973624407530268, 'reg_alpha': 0.9652548629505593, 'min_child_weight': 4}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:37,042] Trial 72 finished with value: 0.39160843424341213 and parameters: {'n_estimators': 527, 'max_depth': 5, 'learning_rate': 0.022400665730283965, 'subsample': 0.6513131370602528, 'colsample_bytree': 0.8082386900348995, 'gamma': 4.904057545389487, 'reg_lambda': 0.37797912733869854, 'reg_alpha': 1.5649755506379706, 'min_child_weight': 5}. Best is trial 28 with value: 0.39819187623991825.
# [I 2025-09-29 21:33:39,640] Trial 73 finished with value: 0.4015003446839188 and parameters: {'n_estimators': 716, 'max_depth': 5, 'learning_rate': 0.0331484250880329, 'subsample': 0.5143355454285767, 'colsample_bytree': 0.5279358138670488, 'gamma': 3.8119737375255682, 'reg_lambda': 0.07586807187269423, 'reg_alpha': 0.4273404993193934, 'min_child_weight': 5}. Best is trial 73 with value: 0.4015003446839188.
# [I 2025-09-29 21:33:40,561] Trial 74 finished with value: 0.40106345313026737 and parameters: {'n_estimators': 809, 'max_depth': 4, 'learning_rate': 0.03355102497447818, 'subsample': 0.5725039282394803, 'colsample_bytree': 0.5676029165083499, 'gamma': 4.221083252821574, 'reg_lambda': 0.07069665190208035, 'reg_alpha': 0.35134014167205285, 'min_child_weight': 4}. Best is trial 73 with value: 0.4015003446839188.
# [I 2025-09-29 21:33:41,444] Trial 75 finished with value: 0.39050931935754785 and parameters: {'n_estimators': 731, 'max_depth': 4, 'learning_rate': 0.034470358881591806, 'subsample': 0.5724210211480811, 'colsample_bytree': 0.5168077122499953, 'gamma': 3.4746558711937046, 'reg_lambda': 0.1324282209104646, 'reg_alpha': 0.4255374261711365, 'min_child_weight': 3}. Best is trial 73 with value: 0.4015003446839188.
# [I 2025-09-29 21:33:42,367] Trial 76 finished with value: 0.40434912899156056 and parameters: {'n_estimators': 781, 'max_depth': 4, 'learning_rate': 0.04328991961554912, 'subsample': 0.5131436938731899, 'colsample_bytree': 0.531722906302823, 'gamma': 3.8101068964654874, 'reg_lambda': 0.016373977131130917, 'reg_alpha': 0.3149315576971052, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:43,267] Trial 77 finished with value: 0.40185818007077395 and parameters: {'n_estimators': 774, 'max_depth': 3, 'learning_rate': 0.04253587862858993, 'subsample': 0.5179067715599948, 'colsample_bytree': 0.5321247133089928, 'gamma': 3.733455724698999, 'reg_lambda': 0.01093988783897155, 'reg_alpha': 0.29673035128357805, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:44,205] Trial 78 finished with value: 0.39830520498153166 and parameters: {'n_estimators': 787, 'max_depth': 3, 'learning_rate': 0.04448942626154458, 'subsample': 0.5148896401038794, 'colsample_bytree': 0.5975539429817283, 'gamma': 3.75015920423506, 'reg_lambda': 0.017573502971007685, 'reg_alpha': 0.2859018107088503, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:45,091] Trial 79 finished with value: 0.397972843339336 and parameters: {'n_estimators': 771, 'max_depth': 3, 'learning_rate': 0.027323162843168894, 'subsample': 0.5143049873562802, 'colsample_bytree': 0.530632420994777, 'gamma': 3.7099381821362325, 'reg_lambda': 0.01911599782452162, 'reg_alpha': 0.2778777033933029, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:46,009] Trial 80 finished with value: 0.3946626643128919 and parameters: {'n_estimators': 780, 'max_depth': 3, 'learning_rate': 0.026399234689507757, 'subsample': 0.5138902296451665, 'colsample_bytree': 0.5296904429401286, 'gamma': 3.762755699735307, 'reg_lambda': 0.018219133132429677, 'reg_alpha': 0.29815123939148025, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:46,899] Trial 81 finished with value: 0.3985036416589717 and parameters: {'n_estimators': 731, 'max_depth': 3, 'learning_rate': 0.04121537047737788, 'subsample': 0.5134085790356652, 'colsample_bytree': 0.5974163644436602, 'gamma': 4.206542457361204, 'reg_lambda': 0.007966487287838428, 'reg_alpha': 0.2284946420612845, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:47,789] Trial 82 finished with value: 0.3986914521742744 and parameters: {'n_estimators': 741, 'max_depth': 3, 'learning_rate': 0.047345394288903185, 'subsample': 0.5106282589828819, 'colsample_bytree': 0.5908382945945078, 'gamma': 3.7521737040518994, 'reg_lambda': 0.005683753891169495, 'reg_alpha': 0.22189256170616156, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:48,656] Trial 83 finished with value: 0.3961593179151959 and parameters: {'n_estimators': 729, 'max_depth': 3, 'learning_rate': 0.043914976427161474, 'subsample': 0.5002565945289312, 'colsample_bytree': 0.5690509411328557, 'gamma': 3.7364419917078617, 'reg_lambda': 0.004198830554270536, 'reg_alpha': 0.24394314761942912, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:49,749] Trial 84 finished with value: 0.39670881106342 and parameters: {'n_estimators': 800, 'max_depth': 3, 'learning_rate': 0.04048013029370355, 'subsample': 0.5154174197007096, 'colsample_bytree': 0.6236973042616792, 'gamma': 4.049403067392912, 'reg_lambda': 0.008560959478000112, 'reg_alpha': 0.20346002534889562, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:53,188] Trial 85 finished with value: 0.3983641337125078 and parameters: {'n_estimators': 696, 'max_depth': 3, 'learning_rate': 0.034516577031596905, 'subsample': 0.5176672379376397, 'colsample_bytree': 0.5278390764524862, 'gamma': 3.285398956995484, 'reg_lambda': 0.019322802811984913, 'reg_alpha': 0.3405606979319021, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:54,066] Trial 86 finished with value: 0.3917076410749018 and parameters: {'n_estimators': 695, 'max_depth': 3, 'learning_rate': 0.03318458687644514, 'subsample': 0.5529305174289182, 'colsample_bytree': 0.590422494867523, 'gamma': 3.102035215898399, 'reg_lambda': 0.010443311860551823, 'reg_alpha': 0.13507599047220856, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:54,923] Trial 87 finished with value: 0.39255367909549427 and parameters: {'n_estimators': 740, 'max_depth': 3, 'learning_rate': 0.048268299583477746, 'subsample': 0.5235705095343555, 'colsample_bytree': 0.5004210567717859, 'gamma': 3.786709146333599, 'reg_lambda': 0.004952277880378092, 'reg_alpha': 0.34329013700575406, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:55,706] Trial 88 finished with value: 0.39612936769988777 and parameters: {'n_estimators': 669, 'max_depth': 3, 'learning_rate': 0.05943398829440643, 'subsample': 0.541317208455226, 'colsample_bytree': 0.5657505413348279, 'gamma': 3.3271755760684516, 'reg_lambda': 0.013216569627245982, 'reg_alpha': 0.49864392574671945, 'min_child_weight': 5}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:56,551] Trial 89 finished with value: 0.4008169446858606 and parameters: {'n_estimators': 715, 'max_depth': 3, 'learning_rate': 0.04128762211529347, 'subsample': 0.5003021502581183, 'colsample_bytree': 0.5273793450298409, 'gamma': 3.2527054010217484, 'reg_lambda': 0.006794595378162324, 'reg_alpha': 0.20755788806053296, 'min_child_weight': 2}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:57,442] Trial 90 finished with value: 0.3922389957478108 and parameters: {'n_estimators': 711, 'max_depth': 3, 'learning_rate': 0.039709692878121074, 'subsample': 0.5002615767724382, 'colsample_bytree': 0.5306694978317273, 'gamma': 3.300961054825298, 'reg_lambda': 0.0032640693895244874, 'reg_alpha': 0.2095448139702082, 'min_child_weight': 1}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:58,330] Trial 91 finished with value: 0.39193773277380606 and parameters: {'n_estimators': 755, 'max_depth': 3, 'learning_rate': 0.04874079410387867, 'subsample': 0.5132731152896035, 'colsample_bytree': 0.514901977406778, 'gamma': 3.4710116707388754, 'reg_lambda': 0.006999633403581734, 'reg_alpha': 0.11183448414715885, 'min_child_weight': 2}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:33:59,327] Trial 92 finished with value: 0.39343428788027585 and parameters: {'n_estimators': 819, 'max_depth': 3, 'learning_rate': 0.029308028732957563, 'subsample': 0.5401417218743794, 'colsample_bytree': 0.5872262448945188, 'gamma': 3.6213490114328217, 'reg_lambda': 0.022281173316396216, 'reg_alpha': 0.35162781589936287, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:00,170] Trial 93 finished with value: 0.38827643872293116 and parameters: {'n_estimators': 629, 'max_depth': 3, 'learning_rate': 0.03593402470906505, 'subsample': 0.5204342677478927, 'colsample_bytree': 0.6574983401564966, 'gamma': 3.8378691396058713, 'reg_lambda': 0.013876468345466561, 'reg_alpha': 0.263178362667197, 'min_child_weight': 2}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:01,019] Trial 94 finished with value: 0.39067698234366854 and parameters: {'n_estimators': 716, 'max_depth': 3, 'learning_rate': 0.02426902111726536, 'subsample': 0.5548021764758317, 'colsample_bytree': 0.5601236158553947, 'gamma': 4.172295427167943, 'reg_lambda': 0.006197638609907404, 'reg_alpha': 0.15651673066037472, 'min_child_weight': 1}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:01,903] Trial 95 finished with value: 0.39227460193033153 and parameters: {'n_estimators': 794, 'max_depth': 4, 'learning_rate': 0.043704440577816674, 'subsample': 0.510123815051008, 'colsample_bytree': 0.5400517594524868, 'gamma': 4.00629530162427, 'reg_lambda': 0.0011677808130083666, 'reg_alpha': 0.5629251053689256, 'min_child_weight': 4}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:02,793] Trial 96 finished with value: 0.40247836790654556 and parameters: {'n_estimators': 750, 'max_depth': 3, 'learning_rate': 0.06311604406490107, 'subsample': 0.5262405343152853, 'colsample_bytree': 0.6143238468193377, 'gamma': 3.5337757315289724, 'reg_lambda': 0.0029493597231209337, 'reg_alpha': 0.4172523922612662, 'min_child_weight': 5}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:06,352] Trial 97 finished with value: 0.36840715046609196 and parameters: {'n_estimators': 758, 'max_depth': 3, 'learning_rate': 0.09561234680031004, 'subsample': 0.525771906273844, 'colsample_bytree': 0.6091861039048765, 'gamma': 0.07400505210299713, 'reg_lambda': 0.002925733497934462, 'reg_alpha': 0.21279700730947299, 'min_child_weight': 5}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:08,006] Trial 98 finished with value: 0.39206588221717575 and parameters: {'n_estimators': 648, 'max_depth': 3, 'learning_rate': 0.0598125275073195, 'subsample': 0.5362689185795132, 'colsample_bytree': 0.6330507196497324, 'gamma': 3.11995265566682, 'reg_lambda': 0.03841908771664439, 'reg_alpha': 0.09716091424134404, 'min_child_weight': 5}. Best is trial 76 with value: 0.40434912899156056.
# [I 2025-09-29 21:34:08,732] Trial 99 finished with value: 0.395636444823311 and parameters: {'n_estimators': 572, 'max_depth': 3, 'learning_rate': 0.054491404595283385, 'subsample': 0.5609768065437566, 'colsample_bytree': 0.5793828034589052, 'gamma': 3.8538083759956203, 'reg_lambda': 0.012513011549718574, 'reg_alpha': 0.4000357662761393, 'min_child_weight': 3}. Best is trial 76 with value: 0.40434912899156056.

# %%
print(xgb_params)
# Out:
# {'n_estimators': 781, 'max_depth': 4, 'learning_rate': 0.04328991961554912, 'subsample': 0.5131436938731899, 'colsample_bytree': 0.531722906302823, 'gamma': 3.8101068964654874, 'reg_lambda': 0.016373977131130917, 'reg_alpha': 0.3149315576971052, 'min_child_weight': 4}

# %% [markdown]
# ### Threshold Tuning

# %%
def tune_threshold(model, X_val, y_val, beta = 1):
    y_probs = model.predict_proba(X_val)[:, 1]
    precisions, recalls, thresholds = precision_recall_curve(y_val, y_probs)

    f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-6)
    #metric = (1 + beta) * (precisions * recalls) / (precisions + (recalls * beta) + 1e-6)
    best_idx = np.argmax(f1_scores)
    best_threshold = thresholds[best_idx]

    return best_threshold, f1_scores[best_idx]

# %%
xgb_threshold, xgb_f1 = tune_threshold(xgb_model, X_train_encoded, y_train_encoded, 0.1)
print(f"Best Threshold: {xgb_threshold}")
print(f"Best F1 Score: {xgb_f1}")
# Out:
# Best Threshold: 0.5192791223526001
# Best F1 Score: 0.5917998746957573

# %% [markdown]
# ### Evaluate function

# %%
def evaluate_model(model, X_test, y_test, threshold=0.5):
    # Probabilities
    y_probs = model.predict_proba(X_test)[:, 1]

    # Apply threshold
    y_pred = (y_probs >= threshold).astype(int)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    auc = roc_auc_score(y_test, y_probs)
    cm = confusion_matrix(y_test, y_pred)

    # Print neatly
    print("=== Evaluation Metrics (Summary) ===")
    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1-score : {f1:.4f}")
    print(f"ROC AUC  : {auc:.4f}")
    print("\nConfusion Matrix:")
    print(cm)
    return

# %%
# 50 trials
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, xgb_threshold)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.5861
# Precision: 0.3011
# Recall   : 0.5045
# F1-score : 0.3771
# ROC AUC  : 0.6273
#
# Confusion Matrix:
# [[206 130]
#  [ 55  56]]

# %%
# 100 trials
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, xgb_threshold)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.6398
# Precision: 0.3457
# Recall   : 0.5045
# F1-score : 0.4103
# ROC AUC  : 0.6252
#
# Confusion Matrix:
# [[230 106]
#  [ 55  56]]

# %%
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, threshold = 0.40)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.5145
# Precision: 0.2913
# Recall   : 0.6667
# F1-score : 0.4055
# ROC AUC  : 0.6252
#
# Confusion Matrix:
# [[156 180]
#  [ 37  74]]

# %%
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, threshold = 0.395)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.5123
# Precision: 0.2918
# Recall   : 0.6757
# F1-score : 0.4076
# ROC AUC  : 0.6252
#
# Confusion Matrix:
# [[154 182]
#  [ 36  75]]

# %%
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, threshold = 0.3885)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.5078
# Precision: 0.2928
# Recall   : 0.6937
# F1-score : 0.4118
# ROC AUC  : 0.6252
#
# Confusion Matrix:
# [[150 186]
#  [ 34  77]]

# %%
evaluate_model(xgb_model, X_test_encoded, y_test_encoded, threshold = 0.45)
# Out:
# === Evaluation Metrics (Summary) ===
# Accuracy : 0.5615
# Precision: 0.3077
# Recall   : 0.6126
# F1-score : 0.4096
# ROC AUC  : 0.6252
#
# Confusion Matrix:
# [[183 153]
#  [ 43  68]]
